# %%
import sys
sys.path.append("../backend")

# %%
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv(filename="local.env"))

# %%
from langchain.chains import QAGenerationChain
from config import config
# Out:
# connecting to database:  localhost 5432 ai4esg

# %%
for key, value in config.__dict__.items():
    print(f'{key}={value}')
# Out:
# openai_api_key=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
# azure_openai_key=5c290765f18449559375b6108879be23
# api_endpoint=http://127.0.0.1:8000/v1
# api_version=2023-05-15
# azure_gpt4_deployment_name=AI4ESGGPT4
# embedding_model=text-embedding-ada-002
# chunk_size=1024
# overlap_size=0
# max_content=3
# prompt_size=6000
# add_title=True
# answer_do_not_know=False
# temperature=0.0001
# db_user=postgres
# db_pass=postgres
# db_host=localhost
# db_port=5432
# db_name=ai4esg

# %%
import openai

openai.api_key = config.azure_openai_key
openai.api_base = config.api_endpoint
openai.api_version = "2023-05-15"

# %%
from backend.modules.document.utils.token_utils import TokenStats

token_stats = TokenStats()

# %%
from langchain.chat_models import AzureChatOpenAI
from langchain.evaluation.qa import QAGenerateChain

chatOpenAI = AzureChatOpenAI(
    temperature=0.0,
    deployment_name=config.azure_gpt4_deployment_name,
    openai_api_base=openai.api_base,
    openai_api_version=openai.api_version,
    openai_api_key=openai.api_key
)
# Out:
# C:\Users\onan\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.azure_openai.AzureChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import AzureChatOpenAI`.
#   warn_deprecated(
# C:\Users\onan\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\langchain_community\chat_models\azure_openai.py:167: UserWarning: As of openai>=1.0.0, Azure endpoints should be specified via the `azure_endpoint` param not `openai_api_base` (or alias `base_url`). Updating `openai_api_base` from https://ai4esg-openai-swe.openai.azure.com/ to https://ai4esg-openai-swe.openai.azure.com/openai.
#   warnings.warn(
# C:\Users\onan\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\langchain_community\chat_models\azure_openai.py:174: UserWarning: As of openai>=1.0.0, if `deployment_name` (or alias `azure_deployment`) is specified then `openai_api_base` (or alias `base_url`) should not be. Instead use `deployment_name` (or alias `azure_deployment`) and `azure_endpoint`.
#   warnings.warn(
# C:\Users\onan\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\langchain_community\chat_models\azure_openai.py:182: UserWarning: As of openai>=1.0.0, if `openai_api_base` (or alias `base_url`) is specified it is expected to be of the form https://example-resource.azure.openai.com/openai/deployments/example-deployment. Updating https://ai4esg-openai-swe.openai.azure.com/ to https://ai4esg-openai-swe.openai.azure.com/openai.
#   warnings.warn(

# %%
qa_prompt_multi = '''You are a legal expert and a teacher coming up with questions to ask on a quiz about ESG regulations. \
\nGiven the following legal document, please generate {num_questions} questions and corresponding answers based on that document. \
\nGenerate only short questions without compound sentences. Generate a variety of questions that cover different aspects about the document. \
\nImportant: In the questions use a variety of question words such as: why, how, where, when, who, which. \
\n Here are some topic ideas for the questions: 
    1. requirements for compliance
    2. penalties for non-compliance
    3. to whom the regulations apply
    4. criteria for applicability of this regulation
\nOnly if the document does not contain information about those topics, include your own. \
\nMake sure they are complete questions, and that they can be answered by extracting excerpts from the document. \
\nEach answer must be composed of an exactly copied excerpt from the document.\
\n\nThese questions and answers should be detailed and be based explicitly on information in the document. \
\n{format_instructions} \
\nBegin! \
\n\n<Begin Document>\n{doc}\n<End Document>'''

# %%
from langchain_core.pydantic_v1 import BaseModel, Field

class Answer(BaseModel):
    text: str = Field(description="Answer text")
    

class QA(BaseModel):
    question: str = Field(description="Question text")
    answers: list[Answer] = Field(description="List of answers")

class QAS(BaseModel):
    qas: list[QA] = Field(description="List of questions and answers")

# %%
qa_gen_chain = QAGenerateChain.from_string(chatOpenAI, qa_prompt_multi)
qa_gen_chain.verbose = True
qa_gen_chain.output_key = "response"

# %%
from langchain.output_parsers.json import SimpleJsonOutputParser

output_parser = SimpleJsonOutputParser(pydantic_object=QAS)

qa_gen_chain.output_parser = output_parser

# %%
qa_gen_chain.output_parser
# Out:
# JsonOutputParser(pydantic_object=<class '__main__.QAS'>)

# %%
output_parser.get_format_instructions()
# Out:
# 'The output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"qas": {"title": "Qas", "description": "List of questions and answers", "type": "array", "items": {"$ref": "#/definitions/QA"}}}, "required": ["qas"], "definitions": {"Answer": {"title": "Answer", "type": "object", "properties": {"text": {"title": "Text", "description": "Answer text", "type": "string"}}, "required": ["text"]}, "QA": {"title": "QA", "type": "object", "properties": {"question": {"title": "Question", "description": "Question text", "type": "string"}, "answers": {"title": "Answers", "description": "List of answers", "type": "array", "items": {"$ref": "#/definitions/Answer"}}}, "required": ["question", "answers"]}}}\n```'

# %%
format_instructions = output_parser.get_format_instructions()

# %%
for key in qa_gen_chain.prompt.__dict__:
    print(f'{key}')
# Out:
# name
# input_variables
# input_types
# output_parser
# partial_variables
# metadata
# tags
# template
# template_format
# validate_template

# %%
qa_gen_chain.prompt
# Out:
# PromptTemplate(input_variables=['doc', 'format_instructions', 'num_questions'], template='You are a legal expert and a teacher coming up with questions to ask on a quiz about ESG regulations. \nGiven the following legal document, please generate {num_questions} questions and corresponding answers based on that document. \nGenerate only short questions without compound sentences. Generate a variety of questions that cover different aspects about the document. \nImportant: In the questions use a variety of question words such as: why, how, where, when, who, which. \n Here are some topic ideas for the questions: \n    1. requirements for compliance\n    2. penalties for non-compliance\n    3. to whom the regulations apply\n    4. criteria for applicability of this regulation\n\nOnly if the document does not contain information about those topics, include your own. \nMake sure they are complete questions, and that they can be answered by extracting excerpts from the document. \nEach answer must be composed of an exactly copied excerpt from the document.\n\nThese questions and answers should be detailed and be based explicitly on information in the document. \n{format_instructions} \nBegin! \n\n<Begin Document>\n{doc}\n<End Document>')

# %%
num_questions = 2

# %%
## Get document for chain here
from modules.document.service import get_all_titles
titles = get_all_titles()
excluded = [
    "Gesetz über das Inverkehrbringen, die Rücknahme und die umweltverträgliche Entsorgung von Batterien und Akkumulatoren (Batteriegesetz - BattG)",
    "REGULATION (EU) 2019/2088 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL of 27 November 2019 on sustainability‐related disclosures in the financial services sector (Text with EEA relevance)",
    "Indian Standard GUIDELINES FOR RECYCLING OF PLASTICS",
    "Union REGULATION (EU) 2020/852 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL of 18 June 2020",
    "DIRECTIVE 2008/98/EC OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL of 19 November 2008 on waste and repealing certain Directives (Text with EEA relevance)",
    "DIRECTIVES DIRECTIVE (EU) 2022/2464 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL",
    "REGULATION (EU) 2023/1542 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL of 12 July 2023 concerning batteries and waste batteries, amending Directive 2008/98/EC and Regulation (EU) 2019/1020 and repealing Directive 2006/66/EC (Text with EEA relevance)",
    "EXPLANATORY MEMORANDUM COMMISSION DELEGATED REGULATION (EU) of 6.7.2021 supplementing Regulation (EU) 2020/852 of the European Parliament and of the Council"
]
titles = list(set(titles) - set(excluded))
print(len(titles))
sorted(titles)
# Out:
# 1
# ['Act on Corporate Due Diligence Obligations for the Prevention of Human Rights Violations in Supply Chains (Lieferkettensorgfaltspflichtengesetz – LkSG)']

# %%
from modules.embedding.service import get_all
from modules.document.service import get_by_title
title = "Act on Corporate Due Diligence Obligations for the Prevention of Human Rights Violations in Supply Chains (Lieferkettensorgfaltspflichtengesetz – LkSG)"
document = get_by_title(title)
embeds = get_all(title=title)
len(embeds)
# Out:
# 39

# %%
doc_for_qas = "\n\n".join([embed.text for embed in embeds[0:3]])
doc_for_qas
# Out:
# '1\n\nAct on Corporate Due Diligence Obligations in Supply Chains Of July 16 2021 The Bundestag has passed the following Act:\n\nArticle 1\n\nAct on Corporate Due Diligence Obligations for the Prevention of Human Rights Violations in Supply Chains (Lieferkettensorgfaltspflichtengesetz – LkSG)\n\nDivision 1 General provisions\n\nSection 1 Scope of application\n\n(1) This Act applies to enterprises regardless of their legal form that\n\n1. have their central administration, their principal place of business, their administrative headquarters or their statutory seat in Germany and\n\n2. that normally have at least 3,000 employees in Germany; employees posted abroad are included.\n\nNotwithstanding sentence 1 no. 1, this Act also applies to enterprises regardless of their legal form that\n\n1. have a domestic branch office pursuant to section 13d of the Commercial Code (Handelsgesetzbuch – HGB) and\n\n2. that normally have at least 3,000 employees in Germany.\n\nFrom 1 January 2024 the thresholds stipulated in sentence 1 no. 2 and sentence 2 no. 2 amount to 1,000 employees, respectively.\n\n(2) Temporary agency workers must be included in the calculation of the number of employees (paragraph (1) sentence 1 no. 2 and sentence 2 no. 2) of the user enterprise if the duration of the assignment exceeds six months.\n\n(3) Within affiliated enterprises (section 15 of the Stock Corporation Act [Aktiengesetz – AktG]), the employees of all enterprises belonging to the group who are employed in Germany must be taken into account when calculating the number of employees (paragraph (1) sentence 1 no. 2) of the parent company; employees posted abroad are included.\n\n2\n\nSection 2 Definitions\n\n(1) Protected legal positions within the meaning of this Act are those arising from the conventions on the protection of human rights listed in nos. 1 to 11 of the Annex.\n\n(2) A human rights risk within the meaning of this Act is a condition in which, on the basis of factual circumstances, there is a sufficient probability that a violation of one of the following prohibitions is imminent:\n\n1. the prohibition of the employment of a child under the age at which compulsory schooling ends according to the law of the place of employment, provided that the age of employment is not less than 15 years, except where the law of the place of employment so provides in accordance with Article 2 (4) and Articles 4 to 8 of Convention No. 138 of the International Labour Organization of 26 June 1973 concerning Minimum Age for Admission to Employment (Federal Law Gazette 1976 II pp. 201, 202);\n\n2. the prohibition of the worst forms of child labour for children under 18 years of age; in accordance with Article 3 of Convention No. 182 of the International Labour Organization of 17 June 1999 concerning the Prohibition and Immediate Action for the Elimination of the Worst Forms of Child Labour (Federal Law Gazette 2001 II pp. 1290, 1291) this includes:\n\na) all forms of slavery or practices similar to slavery, such as the sale and trafficking of children, debt bondage and serfdom, as well as forced or compulsory labour, including the forced or compulsory recruitment of children for use in armed conflicts,\n\nb) the use, procuring or offering of a child for prostitution, for the production of pornography or for pornographic performances,\n\nc) the use, procuring or offering of a child for illicit activities, in particular for the production of or trafficking in drugs,\n\nd) work which, by its nature or the circumstances in which it is carried out, is likely to harm the health, safety or morals of children;\n\n3. the prohibition of the employment of persons in forced labour; this includes any work or service that is required of a person under threat of punishment and for which he or she has not made himself or herself available voluntarily, for example as a result of debt bondage or trafficking in human beings; excluded from forced labour are any work or services that  ...

# %%
token_stats.get_stats(doc_for_qas)
# Out:
# {'avg_tokens_per_page': 1.0,
#  'total_document_tokens': 4293,
#  'max_tokens_per_page': 1}

# %%
prompts = qa_gen_chain.prep_prompts([{"doc": doc_for_qas, "num_questions": num_questions, "format_instructions": format_instructions}])

# %%
prompts[0]
# Out:
# [StringPromptValue(text='You are a legal expert and a teacher coming up with questions to ask on a quiz about ESG regulations. \nGiven the following legal document, please generate 2 questions and corresponding answers based on that document. \nGenerate only short questions without compound sentences. Generate a variety of questions that cover different aspects about the document. \nImportant: In the questions use a variety of question words such as: why, how, where, when, who, which. \n Here are some topic ideas for the questions: \n    1. requirements for compliance\n    2. penalties for non-compliance\n    3. to whom the regulations apply\n    4. criteria for applicability of this regulation\n\nOnly if the document does not contain information about those topics, include your own. \nMake sure they are complete questions, and that they can be answered by extracting excerpts from the document. \nEach answer must be composed of an exactly copied excerpt from the document.\n\nThese questions and answers should be detailed and be based explicitly on information in the document. \nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"qas": {"title": "Qas", "description": "List of questions and answers", "type": "array", "items": {"$ref": "#/definitions/QA"}}}, "required": ["qas"], "definitions": {"Answer": {"title": "Answer", "type": "object", "properties": {"text": {"title": "Text", "description": "Answer text", "type": "string"}}, "required": ["text"]}, "QA": {"title": "QA", "type": "object", "properties": {"question": {"title": "Question", "description": "Question text", "type": "string"}, "answers": {"title": "Answers", "description": "List of answers", "type": "array", "items": {"$ref": "#/definitions/Answer"}}}, "required": ["question", "answers"]}}}\n``` \nBegin! \n\n<Begin Document>\n1\n\nAct on Corporate Due Diligence Obligations in Supply Chains Of July 16 2021 The Bundestag has passed the following Act:\n\nArticle 1\n\nAct on Corporate Due Diligence Obligations for the Prevention of Human Rights Violations in Supply Chains (Lieferkettensorgfaltspflichtengesetz – LkSG)\n\nDivision 1 General provisions\n\nSection 1 Scope of application\n\n(1) This Act applies to enterprises regardless of their legal form that\n\n1. have their central administration, their principal place of business, their administrative headquarters or their statutory seat in Germany and\n\n2. that normally have at least 3,000 employees in Germany; employees posted abroad are included.\n\nNotwithstanding sentence 1 no. 1, this Act also applies to enterprises regardless of their legal form that\n\n1. have a domestic branch office pursuant to section 13d of the Commercial Code (Handelsgesetzbuch – HGB) and\n\n2. that normally have at least 3,000 employees in Germany.\n\nFrom 1 January 2024 the thresholds stipulated in sentence 1 no. 2 and sentence 2 no. 2 amount to 1,000 employees, respectively.\n\n(2) Temporary agency workers must be included in the calculation of the number of employees (paragraph (1) sentence 1 no. 2 and sentence 2 no. 2) of the user enterprise if the duration of the assignment exceeds six months.\n\n(3) Within affiliated enterprises (section 15 of the Stock Corporation Act [Aktiengesetz – AktG]), the employees of all enterprises belonging to the group who are employed in Germany must be taken into account when calculating the number of employees (paragraph (1) sentence 1 no. 2) of the parent company; employees posted abroad are included.\n\n2\n\nSection 2 Definitions\n\n(1) Protected legal positions within the meaning of  ...

# %%
token_stats.get_stats(prompts[0][0].text)
# Out:
# {'avg_tokens_per_page': 1.0,
#  'total_document_tokens': 6497,
#  'max_tokens_per_page': 1}

# %%
print([f'{title}\n' for title in titles])
# Out:
# ['Act on Corporate Due Diligence Obligations for the Prevention of Human Rights Violations in Supply Chains (Lieferkettensorgfaltspflichtengesetz – LkSG)\n']

# %%
# Data generation loop
from uuid import uuid4
import json
import os
#
file_path = "../data/generated/generated_qas_results.json"
#
#data = {"data": []}
#if os.path.exists(file_path):
#    with open(file_path, "r", encoding="utf8") as f:
#        data = json.load(f)
#
#data_item = {
#    "source": document.source,
#    "title": document.title,
#    "paragraphs": []
#}
#data["data"].append(data_item)
#step = 3
##for i in range(0, len(embeds), step):
#for i in range(0, len(embeds), step):
#    current_embeds = embeds[i:i+step]
#    doc_for_qas = str("\n\n".join([embed.text for embed in current_embeds]))
#    page_numbers = list(sorted(set([embed.page_number for embed in current_embeds])))
#    embed_ids = list(str(embed.id) for embed in current_embeds)
#    generated_qas = qa_gen_chain.apply(
#        [{"doc": doc_for_qas, "num_questions": num_questions, "format_instructions": format_instructions}]
#    )
#    paragraph = {
#        "qas": generated_qas[0]["response"]["qas"],
#        "context": doc_for_qas,
#        "embedding_ids": embed_ids,
#        "page_numbers": page_numbers
#    }
#    
#    for qa in paragraph["qas"]:
#        qa["id"] = str(uuid4())
#    
#    data_item["paragraphs"].append(paragraph)
#    print(f"saving data to {file_path}, pages: {page_numbers}")
#    with open(file_path, "w", encoding="utf8") as f:
#        json.dump(data, f, indent=4, ensure_ascii=False)

# %%
#generated_qas = qa_gen_chain.apply(
#    [{"doc": doc_for_qas, "num_questions": num_questions, "format_instructions": format_instructions}]
#)#[qa_gen_chain.output_key]

# %%
#generated_qas[0][qa_gen_chain.output_key]
#generated_qas

#for item in generated_qas[0]["response"]["qas"]:
#    item["context"] = "inserted context"
#    
#generated_qas

# %%
#token_stats.get_stats(str(generated_qas))

# %%
# Calculate number of questions and answers

from modules.document.utils.policyqa_parser import *

file_path = "../data/generated/generated_qas_clean.json"


num_questions = count_questions(file_path)
num_answers = count_answers(file_path)
avg_answer_size = calculate_avg_answer_size(file_path)
min_answer_size, max_answer_size = calculate_min_max_answer_size(file_path)
min_context_size, max_context_size = calculate_min_max_context_size(file_path)

print(f"Number of questions: {num_questions}")
print(f"Number of answers: {num_answers}")
print(f"Average answer size: {avg_answer_size}")
print(f"Min answer size: {min_answer_size}")
print(f"Max answer size: {max_answer_size}")
print(f"Min context size: {min_context_size}")
print(f"Max context size: {max_context_size}")
# Out:
# Number of questions: 539
# Number of answers: 539
# Average answer size: 326.5769944341373
# Min answer size: 4
# Max answer size: 1252
# Min context size: 36
# Max context size: 5791

# %% [markdown]
# ## Check whether all answers are in the context

# %%
import json

import re

def remove_numbers_in_parentheses(s):
    return re.sub(r'\(\d{1,2}\)', '', s)

def replace_multiple_spaces(s):
    return re.sub(' +', ' ', s)

file_path = "../data/generated/generated_qas_clean.json"

answers_not_in_context = []
answers_in_context = []

with open(file_path, "r", encoding="utf8") as f:
    count = 0
    data = json.load(f)
    for item in data["data"]:
        title = item["title"]
        source = item["source"]
        for paragraph in item["paragraphs"]:
            for qa in paragraph["qas"]:
                question_id = qa["id"]
                question_text = str(qa["question"])
                for answer in qa["answers"]:
                    answer_text = str(answer["text"])
                    context = str(paragraph["context"])
                    #answer_text = answer_text.replace("\n", " ")
                    #context = context.replace("\n", " ")
                    #answer_text = replace_multiple_spaces(answer_text)
                    #context = replace_multiple_spaces(context)
                    #answer_text = remove_numbers_in_parentheses(answer_text)
                    #context = remove_numbers_in_parentheses(context)
                    answer_text = answer_text.lower()
                    context = context.lower()
                    answer_text = " ".join(answer_text.split())
                    context = " ".join(context.split())
                    if answer_text.endswith("."):
                        answer_text = answer_text[:-1]
                    if answer_text not in context:
                        print(f"##############")
                        print(f"Answer not in context for question: {qa['id']}")
                        print(f"##############")
                        print(answer_text)
                        print(f"##############")
                        print(context)
                        count += 1
                        answers_not_in_context.append({
                            "id": question_id,
                            "question": question_text,
                            "answer": answer_text,
                            "context": context,
                            "title": title,
                            "source": source
                        })
                    else:
                        answers_in_context.append({
                            "id": question_id,
                            "question": question_text,
                            "answer": answer_text,
                            "context": context,
                            "title": title,
                            "source": source
                        })
                        
    print(f"Total number of answers not in context: {count}")
# Out:
# Total number of answers not in context: 0

# %%
import pandas as pd

answer_not_in_context_df = pd.DataFrame(answers_not_in_context)
answer_in_context_df = pd.DataFrame(answers_in_context)

len(answer_not_in_context_df)
# Out:
# 0

# %%
n = 0
for i in range(n, n+1):
    answer = ""
    context = answer_not_in_context_df.iloc[i]["context"]
    source = answer_not_in_context_df.iloc[i]["source"]
    found_index = -1
    q_id = answer_not_in_context_df.iloc[i]["id"]
    for word in answer_not_in_context_df.iloc[i]["answer"].split():
        answer += f"{word} "
        try:
            found_index = context.index(answer)
        except ValueError:
            answer_len = len(answer)
            print(f"source: {source}")
            print(f"question: {answer_not_in_context_df.iloc[i]['question']}")
            print(f"for question id: {q_id}")
            print(f"GT answer: {answer_not_in_context_df.iloc[i]['answer']}")
            print(f"answer: {answer[:-1]}")
            print(f"context: {answer_not_in_context_df.iloc[i]['context'][found_index:found_index+answer_len]}")
            break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[165], line 4
#       2 for i in range(n, n+1):
#       3     answer = ""
# ----> 4     context = answer_not_in_context_df.iloc[i]["context"]
#       5     source = answer_not_in_context_df.iloc[i]["source"]
#       6     found_index = -1
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
answer_not_in_context_df.loc[answer_not_in_context_df["id"] == q_id]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 answer_not_in_context_df.loc[answer_not_in_context_df["id"] == q_id]
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'id'

# %%
"""
                        "47c82065-a2f5-4700-b40b-1db16da9c1b7",
                        "6c843a56-2236-4aa8-b002-d16d22613364",
                        "bdcd1153-904a-45ed-ac8a-e58775448158"
"""

from modules.embedding.service import get as get_embedding_by_id

embedding = get_embedding_by_id("3a2051de-fb9e-40fc-820d-689bc7c989b6")
print(embedding.text)
# Out:
# (c) facilitating the preparation for re-use, preparation for repurposing, repurposing or remanufacturing of the battery.
#
# 3. The battery management system shall include a software reset function, in case economic operators carrying out preparation for re-use, preparation for repurposing, repurposing or remanufacturing need to upload different battery management system software. If the software reset function is used, the original battery manufacturer shall not be held liable for any breach of the safety or functionality of the battery that could be attributed to battery management system software uploaded after that battery was placed on the market.
#
# CHAPTER IV
#
# Conformity of batteries
#
# Article 15
#
# Presumption of conformity of batteries
#
# Official Journal of the European Union
#
# 2. Harmonised standards shall aim to simulate real-life usage as far as possible while maintaining standard tests.
#
# Official Journal of the European Union
#
# Article 16

# %% [markdown]
# ## Remove questions with answers not in context

# %%
len(answer_not_in_context_df["id"].tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 len(answer_not_in_context_df["id"].tolist())
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'id'

# %%
for item in data["data"]:
    for paragraph in item["paragraphs"]:
        for qa in paragraph["qas"]:
            if qa["id"] in answer_not_in_context_df["id"].tolist():
                paragraph["qas"].remove(qa)

#file = "../data/generated/generated_qas_clean.json"
#with open(file, "w", encoding="utf8") as f:
#    json.dump(data, f, indent=4, ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[169], line 4
#       2     for paragraph in item["paragraphs"]:
#       3         for qa in paragraph["qas"]:
# ----> 4             if qa["id"] in answer_not_in_context_df["id"].tolist():
#       5                 paragraph["qas"].remove(qa)
#       7 #file = "../data/generated/generated_qas_clean.json"
#       8 #with open(file, "w", encoding="utf8") as f:
#       9 #    json.dump(data, f, indent=4, ensure_ascii=False)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\ai4esg-MyrZEbvC-py3.11\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'id'

# %% [markdown]
# ## Remove questions with answers that span multiple embeddings

# %%
qs_span_multiple_embeds = ['7ae57dda-b9b1-4e88-be53-a3aaec5a26db', '17f2546f-7a64-43d9-a47f-abc952f91f49', '226111ad-7262-401f-869a-66fc331232bc', '39c1ac2b-b524-4b1c-8861-64f58a3b3b67', '5a43cfb3-2af7-4035-bb4a-4992ca7090e6', '512f0b9d-488f-44bc-8e46-d6af4a3b7069', '60fdca96-3b36-4cd2-8b7a-608734e2ea46', '3c770ce8-6c72-4021-83e3-c98ae17ec745', 'e042d03e-3d23-4183-96e2-96d9cd13a131', 'a7c29aa9-21c6-40d7-a907-e60c83f7f28e', '164d4bdf-a4a4-4922-ab83-50e1ebec34e7', '121c1e65-5c26-4d7d-bc58-6ab3abf1b9dd', '461f01a6-a6bf-4946-bb12-283cfa269541', 'b4b5945a-caf4-4a90-9577-e7255a0344a9', '22f765a6-944d-496b-a796-66f7d31f4f5e', '483bec64-f7b7-4e8e-9059-a33cf0d3c3ea', '001d7c6e-e5a7-4583-9c96-fe3e8cc366ec', 'e3497c6b-3d73-4d27-ad2f-4a05c3cd6da4', 'dcaf8486-4784-46a6-9be2-4ab41553dba5', '7061fc8e-deea-4ad1-bc9b-222c9717ed35', '3a84bc67-dd00-47f9-be65-6413a698f173', '015b9098-1455-40b1-81b8-fb0297d346f1', '9c42f0ef-8e47-4256-87bb-8368420e3a44', '29685aa7-d02e-494f-a66d-4f9ea5e351cd', '4795f35e-0db5-4ddc-828f-a93f78dc8c65', '43abe044-236c-414a-aee3-6e211639bd6d', '8a40e6aa-deaf-4974-84c8-6c1678a54600', '48b23883-f9bc-4f1a-9425-9a219b0ed93d', 'caec996c-8e2d-4cbc-99cf-7647193f0e4d', 'ce0d00a5-1978-4235-a494-b4c3866e2119', 'ef18c7b7-59bd-46e3-802b-a7efb22b79fe', 'ebbbafce-a6f8-468a-9906-63305a1adfea', 'b9740a36-b7b0-42e6-9d17-4f3e4c5bbebe']

# %%
for item in data["data"]:
    for paragraph in item["paragraphs"]:
        for qa in paragraph["qas"]:
            if qa["id"] in qs_span_multiple_embeds:
                paragraph["qas"].remove(qa)

file = "../data/generated/generated_qas_clean.json"
with open(file, "w", encoding="utf8") as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## Remove questions with less than 3 embeddings

# %%
qa_less_than_3_embeds = []

for item in data["data"]:
    for paragraph in item["paragraphs"]:
        if len(paragraph["embedding_ids"]) < 3:
            for qa in paragraph["qas"]:
                qa_less_than_3_embeds.append(qa["id"])

# %%
print([id for id in qa_less_than_3_embeds])
# Out:
# []

# %%
for item in data["data"]:
    for paragraph in item["paragraphs"]:
        for qa in paragraph["qas"]:
            if qa["id"] in qa_less_than_3_embeds:
                paragraph["qas"].remove(qa)

file = "../data/generated/generated_qas_clean.json"
with open(file, "w", encoding="utf8") as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## Split data into train and test

# %%
from modules.document.utils.split_utils import create_qa_train_test_split

create_qa_train_test_split(file_path, split=0.51)
# Out:
# root path: C:\Users\onan\IdeaProjects\ai4esg_experiments_new\data\generated
# the intersection has size 0
# is 390bed57-a631-4986-a794-902e948bf685 in questions_ids? False
# is a299112d-202c-4b94-aa7d-179d0cc6e9e9 in questions_ids? True
# inserting qas with ids ['a299112d-202c-4b94-aa7d-179d0cc6e9e9'] for split train
# paragraph['qas'] size: 1 for split train
# is 6e29f3ea-9dd1-433e-92dc-a691e1ab64f3 in questions_ids? True
# is daa6fcab-6f6c-441f-b704-61d18c237ae1 in questions_ids? False
# inserting qas with ids ['6e29f3ea-9dd1-433e-92dc-a691e1ab64f3'] for split train
# paragraph['qas'] size: 1 for split train
# is 52b903bb-d3d3-47c4-a845-9d460dd9a015 in questions_ids? False
# is bbb365cf-3b71-4aab-b3c5-b5032751ad58 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is b80249b6-cef8-4075-bc63-11f699a60c06 in questions_ids? True
# is fc9b28bc-6d9d-45d5-bc6f-c17515f05b9f in questions_ids? False
# inserting qas with ids ['b80249b6-cef8-4075-bc63-11f699a60c06'] for split train
# paragraph['qas'] size: 1 for split train
# is 9f81e486-0b49-4452-82b8-7d9fabac367a in questions_ids? True
# is 79da3883-4ef8-4b98-9c08-7b4e93835a67 in questions_ids? False
# inserting qas with ids ['9f81e486-0b49-4452-82b8-7d9fabac367a'] for split train
# paragraph['qas'] size: 1 for split train
# is faf4435d-236c-4f96-b2e9-67a8f1c54a97 in questions_ids? True
# is 0edd772e-5cd5-468d-b43f-8c24619bb074 in questions_ids? True
# inserting qas with ids ['faf4435d-236c-4f96-b2e9-67a8f1c54a97', '0edd772e-5cd5-468d-b43f-8c24619bb074'] for split train
# paragraph['qas'] size: 2 for split train
# is 4701665d-a07f-4ed2-8690-8d066b252c09 in questions_ids? False
# is d06a73d2-2a8a-4ec1-931b-c1a1727378ae in questions_ids? True
# inserting qas with ids ['d06a73d2-2a8a-4ec1-931b-c1a1727378ae'] for split train
# paragraph['qas'] size: 1 for split train
# is f1d9e134-21a8-4173-8d14-92e836e80915 in questions_ids? True
# is d75651f2-9b3f-4e24-9a07-f4a8422a7106 in questions_ids? True
# inserting qas with ids ['f1d9e134-21a8-4173-8d14-92e836e80915', 'd75651f2-9b3f-4e24-9a07-f4a8422a7106'] for split train
# paragraph['qas'] size: 2 for split train
# is 2e2d0004-cbab-4ccb-9b93-6d07fdbd44c9 in questions_ids? True
# is 1fc83eae-54d1-4d42-996b-827523574f39 in questions_ids? False
# inserting qas with ids ['2e2d0004-cbab-4ccb-9b93-6d07fdbd44c9'] for split train
# paragraph['qas'] size: 1 for split train
# is 4d10b167-7c54-4951-a9dc-e7d73727f6fe in questions_ids? True
# is f8713591-8797-4517-b2fe-d0bda07c5900 in questions_ids? False
# is f637e729-c768-4584-ac79-7905bcc7580e in questions_ids? True
# inserting qas with ids ['4d10b167-7c54-4951-a9dc-e7d73727f6fe', 'f637e729-c768-4584-ac79-7905bcc7580e'] for split train
# paragraph['qas'] size: 2 for split train
# is 088ce6ea-f456-4100-a4a3-ea278c7ffbc9 in questions_ids? True
# is b4f72358-e201-4514-8a62-93738ff26403 in questions_ids? False
# inserting qas with ids ['088ce6ea-f456-4100-a4a3-ea278c7ffbc9'] for split train
# paragraph['qas'] size: 1 for split train
# is ec2ae519-c096-4505-b997-ef83c4941e9e in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is e8a50210-8176-4fcc-9378-23cccb5da013 in questions_ids? False
# is 7c3f4041-e939-4ecc-8576-93eb3ede32df in questions_ids? True
# inserting qas with ids ['7c3f4041-e939-4ecc-8576-93eb3ede32df'] for split train
# paragraph['qas'] size: 1 for split train
# is f93fa4c2-2efd-4581-a252-d04006874738 in questions_ids? False
# is d10a7095-1695-490b-a307-f3c0b021a354 in questions_ids? True
# inserting qas with ids ['d10a7095-1695-490b-a307-f3c0b021a354'] for split train
# paragraph['qas'] size: 1 for split train
# is f78bde0f-bd9b-4bc3-b1ba-e45a837611c3 in questions_ids? False
# is 5612657a-860d-43db-ac51-106d832e121b in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 71764f7a-417a-4e02-9b8f-bfbab17563be in questions_ids? False
# is 1d5d0d2a-85dd-40c1-99c9-a6e2f3264f37 in questions_ids? True
# inserting qas with ids ['1d5d0d2a-85dd-40c1-99c9-a6e2f3264f37'] for split train
# paragraph['qas'] size: 1 for split train
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is a807f2e7-505f-4ab5-b592-c8ea07def5f8 in questions_ids? True
# is b9ff5b9f-0645-4d35-80e6-2c3213a26792 in questions_ids? True
# inserting qas with ids ['a807f2e7-505f-4ab5-b592-c8ea07def5f8', 'b9ff5b9f-0645-4d35-80e6-2c3213a26792'] for split train
# paragraph['qas'] size: 2 for split train
# is 087551f8-b981-41fa-8414-bf4833829e0c in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is dd5258de-3fe5-41e1-b170-460181d25534 in questions_ids? False
# is 219e83b2-5e32-4047-a873-4de3758de297 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 12a7c564-eade-45b3-a2f0-362c2e95e62c in questions_ids? True
# is 53f6d514-98c2-4f97-aa13-5768734cc219 in questions_ids? False
# inserting qas with ids ['12a7c564-eade-45b3-a2f0-362c2e95e62c'] for split train
# paragraph['qas'] size: 1 for split train
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 3fb6ba2a-398a-4f6d-9820-a1f7cd5ba91c in questions_ids? False
# is b4866a97-94d0-45f9-82f3-161a8334c8ca in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 785cc1d7-d06d-4d66-b352-c6f3429b82d0 in questions_ids? False
# is da768d7e-5e8e-4202-b1ec-05bec30de586 in questions_ids? True
# inserting qas with ids ['da768d7e-5e8e-4202-b1ec-05bec30de586'] for split train
# paragraph['qas'] size: 1 for split train
# is a9aebd74-2020-4907-aaa8-20b1e694b7ca in questions_ids? False
# is 05284d12-aa35-4a2b-9576-6c970ef8816d in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 3ccbaf7a-7aa3-4f93-818e-851d74e11647 in questions_ids? False
# is e74bffa4-eef0-4230-9607-7c11994e97cb in questions_ids? True
# inserting qas with ids ['e74bffa4-eef0-4230-9607-7c11994e97cb'] for split train
# paragraph['qas'] size: 1 for split train
# is a05ed403-9305-4a50-b0d7-07995849d2d0 in questions_ids? True
# is 59166e26-2241-46b9-8ab9-a722dafcd9a8 in questions_ids? True
# inserting qas with ids ['a05ed403-9305-4a50-b0d7-07995849d2d0', '59166e26-2241-46b9-8ab9-a722dafcd9a8'] for split train
# paragraph['qas'] size: 2 for split train
# is 2107b9ad-90be-4159-9847-7bac042641ab in questions_ids? True
# is 4de465a6-0920-4e85-afde-15d0da9bc880 in questions_ids? True
# inserting qas with ids ['2107b9ad-90be-4159-9847-7bac042641ab', '4de465a6-0920-4e85-afde-15d0da9bc880'] for split train
# paragraph['qas'] size: 2 for split train
# is 9cb73382-1f5b-40a7-bcfc-8b3414e7319f in questions_ids? False
# is c6975fbc-20c9-45e7-b091-6c301034ca81 in questions_ids? True
# inserting qas with ids ['c6975fbc-20c9-45e7-b091-6c301034ca81'] for split train
# paragraph['qas'] size: 1 for split train
# is 951eb244-8fb4-4326-a937-4a25383f9bca in questions_ids? True
# is c113a107-8db5-47e0-819f-5a8d5db6246a in questions_ids? True
# inserting qas with ids ['951eb244-8fb4-4326-a937-4a25383f9bca', 'c113a107-8db5-47e0-819f-5a8d5db6246a'] for split train
# paragraph['qas'] size: 2 for split train
# is f599a62b-ef2e-47e1-9032-b5d3c0850b41 in questions_ids? False
# is 61551cbd-4013-4fc9-b00d-dfc83e228ad6 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 73c094a2-c6a7-4c37-a845-27fa669b5614 in questions_ids? False
# is bf636f13-68e8-4dbd-941e-ec51eee9d40e in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 97ba6c2c-8fae-4caf-b814-ffbc97a754ab in questions_ids? True
# is 0cc4958c-0661-429c-8d17-ceb71f7a052d in questions_ids? False
# inserting qas with ids ['97ba6c2c-8fae-4caf-b814-ffbc97a754ab'] for split train
# paragraph['qas'] size: 1 for split train
# is e671ac51-b229-4b26-bc6e-4ce4975db842 in questions_ids? False
# is 0217545e-3cf1-43ca-a454-202dcbd82640 in questions_ids? True
# inserting qas with ids ['0217545e-3cf1-43ca-a454-202dcbd82640'] for split train
# paragraph['qas'] size: 1 for split train
# is 2b306a96-26b7-4691-b543-9237062e6029 in questions_ids? True
# is 0a602119-f234-4774-88b5-31f940ac3983 in questions_ids? True
# inserting qas with ids ['2b306a96-26b7-4691-b543-9237062e6029', '0a602119-f234-4774-88b5-31f940ac3983'] for split train
# paragraph['qas'] size: 2 for split train
# is 8e3724be-ac44-4e2c-b9e7-5ca95fc8db7b in questions_ids? True
# is 70b51fb5-a540-43f4-a248-5a13ca130621 in questions_ids? True
# inserting qas with ids ['8e3724be-ac44-4e2c-b9e7-5ca95fc8db7b', '70b51fb5-a540-43f4-a248-5a13ca130621'] for split train
# paragraph['qas'] size: 2 for split train
# is caf9a467-2f73-4dc6-b022-a0ff7eaeea8b in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is f7bbb89e-5215-4408-967d-85f7ea88a0bd in questions_ids? False
# is c9fdb6ca-6585-49bb-92b2-c1fdfdda058f in questions_ids? True
# inserting qas with ids ['c9fdb6ca-6585-49bb-92b2-c1fdfdda058f'] for split train
# paragraph['qas'] size: 1 for split train
# is 97c14349-c90f-48ff-be5f-4e435bb538e6 in questions_ids? False
# is ece613f2-8f83-4ffa-af71-f0da6751424d in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 70b14ef8-0f56-44d2-aa38-5a5dea5cc732 in questions_ids? True
# is 9d22ba52-9755-4ccb-9b2f-ab01da37cbdc in questions_ids? False
# inserting qas with ids ['70b14ef8-0f56-44d2-aa38-5a5dea5cc732'] for split train
# paragraph['qas'] size: 1 for split train
# is 7c786964-5ed4-4148-8ece-a8dd50592321 in questions_ids? True
# is d71cec86-5618-4ddf-8973-5ccb47883628 in questions_ids? True
# inserting qas with ids ['7c786964-5ed4-4148-8ece-a8dd50592321', 'd71cec86-5618-4ddf-8973-5ccb47883628'] for split train
# paragraph['qas'] size: 2 for split train
# is e0fc12ac-9808-44fe-9bc6-4176a27c56f4 in questions_ids? False
# is 8248dd63-f5dc-4abc-8a56-42c74577d43b in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 9082690b-dda3-46fe-ad2b-8644b6e1b720 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 3e06f40c-9294-43a7-aa1a-69a3a8c95e24 in questions_ids? True
# inserting qas with ids ['3e06f40c-9294-43a7-aa1a-69a3a8c95e24'] for split train
# paragraph['qas'] size: 1 for split train
# is a59c26a7-26e1-473b-a677-820e089e1b2c in questions_ids? True
# inserting qas with ids ['a59c26a7-26e1-473b-a677-820e089e1b2c'] for split train
# paragraph['qas'] size: 1 for split train
# is 78ddaeec-260e-4e87-81da-a9daaca540f2 in questions_ids? False
# is d5720df2-bdcd-4930-9b75-615f584a28c3 in questions_ids? True
# inserting qas with ids ['d5720df2-bdcd-4930-9b75-615f584a28c3'] for split train
# paragraph['qas'] size: 1 for split train
# is 54f96e06-46c5-48df-8f0c-89113758b7db in questions_ids? True
# inserting qas with ids ['54f96e06-46c5-48df-8f0c-89113758b7db'] for split train
# paragraph['qas'] size: 1 for split train
# is d5d484aa-e220-41f3-b758-c4b7ff8c227f in questions_ids? True
# inserting qas with ids ['d5d484aa-e220-41f3-b758-c4b7ff8c227f'] for split train
# paragraph['qas'] size: 1 for split train
# is 78e34b04-e80b-4ec8-b392-286bba94c75f in questions_ids? False
# is f556bf19-6dee-44b6-b176-f6d316c20d75 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is d42db42b-f393-42b2-8f0b-be49a1b7a62d in questions_ids? True
# is 35f41577-885e-4790-8b76-dde8755b049f in questions_ids? True
# inserting qas with ids ['d42db42b-f393-42b2-8f0b-be49a1b7a62d', '35f41577-885e-4790-8b76-dde8755b049f'] for split train
# paragraph['qas'] size: 2 for split train
# is e3ad1a4b-e04a-4e7f-aa2b-9858dc1fee3c in questions_ids? False
# is eee26e85-1c7f-47bb-aeb2-9e021621b6d7 in questions_ids? True
# inserting qas with ids ['eee26e85-1c7f-47bb-aeb2-9e021621b6d7'] for split train
# paragraph['qas'] size: 1 for split train
# is 6ce6b96b-ffe5-4213-8af5-9c1a33a2543a in questions_ids? True
# inserting qas with ids ['6ce6b96b-ffe5-4213-8af5-9c1a33a2543a'] for split train
# paragraph['qas'] size: 1 for split train
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 531dda52-5b8c-4072-a2a6-c2c9af0e8703 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 49cdfc11-77de-4240-95ce-a924290966c7 in questions_ids? True
# is 30860cd8-f523-4ce5-bdde-b472b2d5f433 in questions_ids? True
# inserting qas with ids ['49cdfc11-77de-4240-95ce-a924290966c7', '30860cd8-f523-4ce5-bdde-b472b2d5f433'] for split train
# paragraph['qas'] size: 2 for split train
# is f8f0a388-ef4e-4037-8684-62dbd85bc8e4 in questions_ids? True
# is 9761fb16-32bd-4535-a510-e4854054a397 in questions_ids? True
# inserting qas with ids ['f8f0a388-ef4e-4037-8684-62dbd85bc8e4', '9761fb16-32bd-4535-a510-e4854054a397'] for split train
# paragraph['qas'] size: 2 for split train
# is 2e253217-1d75-46b6-8430-35ba600677b9 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is c64b3dd0-a73a-4570-8c89-97e16addd72c in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 5ad3fadc-9008-463d-bd55-21686aee22a5 in questions_ids? False
# is c989853b-6e79-47c8-ae54-87f9f7448480 in questions_ids? True
# inserting qas with ids ['c989853b-6e79-47c8-ae54-87f9f7448480'] for split train
# paragraph['qas'] size: 1 for split train
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 46decba8-aee5-47c6-80c0-cc684aa26741 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is a6f5a04e-25df-4729-95bd-cfaa358bd3e6 in questions_ids? True
# inserting qas with ids ['a6f5a04e-25df-4729-95bd-cfaa358bd3e6'] for split train
# paragraph['qas'] size: 1 for split train
# is dddf7062-4643-4a3d-8a5b-565e5a9362c1 in questions_ids? False
# is 71694f39-eb43-49c7-9ac0-64fdf00ff305 in questions_ids? True
# inserting qas with ids ['71694f39-eb43-49c7-9ac0-64fdf00ff305'] for split train
# paragraph['qas'] size: 1 for split train
# is 2d01b644-df11-4c6c-8ccc-9cb6d6f45485 in questions_ids? True
# inserting qas with ids ['2d01b644-df11-4c6c-8ccc-9cb6d6f45485'] for split train
# paragraph['qas'] size: 1 for split train
# is 83fb8bcd-51df-4d57-877e-bbf3b70646b9 in questions_ids? True
# inserting qas with ids ['83fb8bcd-51df-4d57-877e-bbf3b70646b9'] for split train
# paragraph['qas'] size: 1 for split train
# is 687e4df5-89ba-4cde-bdc2-8fac500bdf5d in questions_ids? False
# is b11c2230-d42f-4aa2-b8ba-9a71b43525ac in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is d545ff4d-6cea-4950-8738-056ac5329b6a in questions_ids? True
# is 5cbe6ea3-ef02-4d7d-a3d9-4b57369d6347 in questions_ids? False
# inserting qas with ids ['d545ff4d-6cea-4950-8738-056ac5329b6a'] for split train
# paragraph['qas'] size: 1 for split train
# is 92542322-51af-4e77-952a-c78f01e46aa5 in questions_ids? True
# is be0ff979-8e8e-44d3-9905-29197ef54e7f in questions_ids? False
# inserting qas with ids ['92542322-51af-4e77-952a-c78f01e46aa5'] for split train
# paragraph['qas'] size: 1 for split train
# is e7b9360c-ffb4-44be-9cf1-3b16b74b0b32 in questions_ids? False
# is b03fa1ff-c0ad-4794-8a7f-b681908db2df in questions_ids? True
# inserting qas with ids ['b03fa1ff-c0ad-4794-8a7f-b681908db2df'] for split train
# paragraph['qas'] size: 1 for split train
# is 9e0809bb-d5f9-41fb-ad0f-7de7bd156ead in questions_ids? False
# is 7e0a246a-ce23-403c-be85-a4aef2b0b383 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is baa4fc28-42e8-48d6-9b1a-b3a8cf8240e1 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is fe573455-48f7-4112-8604-c4a60f36e0c1 in questions_ids? True
# is 8611f511-2db4-4894-9825-076bc094432c in questions_ids? True
# inserting qas with ids ['fe573455-48f7-4112-8604-c4a60f36e0c1', '8611f511-2db4-4894-9825-076bc094432c'] for split train
# paragraph['qas'] size: 2 for split train
# is a595678e-1328-4aa4-a584-e7fd14b041f0 in questions_ids? False
# is 0ce9a55e-b1df-4bbf-8cfc-a4546d07f1b4 in questions_ids? True
# is c0c1475a-0e75-4abc-9165-d6bae05195b8 in questions_ids? False
# is 76ec4bb9-e1ba-4a31-8b40-6d0eac5cece7 in questions_ids? False
# is a5f1ae27-4f1e-496d-adf0-28694fc125f4 in questions_ids? True
# inserting qas with ids ['0ce9a55e-b1df-4bbf-8cfc-a4546d07f1b4', 'a5f1ae27-4f1e-496d-adf0-28694fc125f4'] for split train
# paragraph['qas'] size: 2 for split train
# is a58ec455-50a8-485d-87bf-361fd09e487a in questions_ids? False
# is 8bdfbbf1-4cb6-4e97-9d1c-095889f19e84 in questions_ids? True
# inserting qas with ids ['8bdfbbf1-4cb6-4e97-9d1c-095889f19e84'] for split train
# paragraph['qas'] size: 1 for split train
# is 0f87f323-afb3-45ae-b89f-4f7fcba4fe5c in questions_ids? False
# is da668b68-a05c-49b1-aaa7-1f103264b8c0 in questions_ids? True
# inserting qas with ids ['da668b68-a05c-49b1-aaa7-1f103264b8c0'] for split train
# paragraph['qas'] size: 1 for split train
# is f2d27d21-92f6-44e5-baf7-5a280a53d085 in questions_ids? True
# is d6efcd20-3d64-4e50-a2b9-d6f8f607c35b in questions_ids? True
# inserting qas with ids ['f2d27d21-92f6-44e5-baf7-5a280a53d085', 'd6efcd20-3d64-4e50-a2b9-d6f8f607c35b'] for split train
# paragraph['qas'] size: 2 for split train
# is 6883ac5e-a58d-4df1-a9f2-64d46e7022ac in questions_ids? False
# is d4ff992b-e9eb-42d7-8192-515993e16dd3 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 8b93118d-73e1-433f-8469-886a95baf939 in questions_ids? True
# inserting qas with ids ['8b93118d-73e1-433f-8469-886a95baf939'] for split train
# paragraph['qas'] size: 1 for split train
# is 17b57719-e34a-4ce6-a087-3a08aa09dcda in questions_ids? False
# is 0870e9a1-2d9d-44e0-ad63-0a6f61a7a270 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 1d59591e-09b4-4f4a-a183-181986d38d78 in questions_ids? False
# is f5f6c975-3c37-4408-81fe-6f4e095857be in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 32faa098-b21e-4fc5-befd-dcb49f76c11f in questions_ids? True
# is efe6e081-9275-4cf7-8542-e9071df2f4f2 in questions_ids? True
# inserting qas with ids ['32faa098-b21e-4fc5-befd-dcb49f76c11f', 'efe6e081-9275-4cf7-8542-e9071df2f4f2'] for split train
# paragraph['qas'] size: 2 for split train
# is 8cb923cb-1e9c-4590-965b-66d30d5a7b08 in questions_ids? False
# is b9937370-489e-466d-8187-b354a4ecd21b in questions_ids? True
# inserting qas with ids ['b9937370-489e-466d-8187-b354a4ecd21b'] for split train
# paragraph['qas'] size: 1 for split train
# is b6c5cfc0-ae0b-43ee-8731-50aea2e66db0 in questions_ids? False
# is 11b8435f-b6ac-40f8-adfd-4ac2ff91cf8a in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is a843c7a0-08a4-4297-ae36-0055d8847e03 in questions_ids? True
# is 9c6d2838-dec5-4903-bc18-439eae708a2f in questions_ids? False
# inserting qas with ids ['a843c7a0-08a4-4297-ae36-0055d8847e03'] for split train
# paragraph['qas'] size: 1 for split train
# is 190ec315-7c0f-4049-8583-76796c5c3510 in questions_ids? True
# is 638324da-b714-4238-8b36-26a1eb4ce58b in questions_ids? True
# inserting qas with ids ['190ec315-7c0f-4049-8583-76796c5c3510', '638324da-b714-4238-8b36-26a1eb4ce58b'] for split train
# paragraph['qas'] size: 2 for split train
# is 3e3807b7-ac01-4881-9fe2-70aed571e379 in questions_ids? False
# is e626d9ed-ca9e-4426-8d7e-48cedb1e03ad in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 0dd10061-89f1-4dc3-b58f-8eb4ace102d6 in questions_ids? True
# is 8039588c-affe-4bcf-890b-5f46ed28ddfc in questions_ids? False
# inserting qas with ids ['0dd10061-89f1-4dc3-b58f-8eb4ace102d6'] for split train
# paragraph['qas'] size: 1 for split train
# is 752fc1db-e522-42f1-a7ba-87261e40918c in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 5ae96672-49b5-4327-b85e-7335e9273472 in questions_ids? True
# inserting qas with ids ['5ae96672-49b5-4327-b85e-7335e9273472'] for split train
# paragraph['qas'] size: 1 for split train
# is 61040bc6-9b21-4789-bf70-51652f7f66db in questions_ids? True
# is 765fc2eb-2eed-4662-83fb-0ceb9b3b9125 in questions_ids? True
# inserting qas with ids ['61040bc6-9b21-4789-bf70-51652f7f66db', '765fc2eb-2eed-4662-83fb-0ceb9b3b9125'] for split train
# paragraph['qas'] size: 2 for split train
# is ee0a1e7c-70d1-4428-aa60-55741821b046 in questions_ids? True
# is 22a4a0b8-ca13-41a3-be12-f36bad46bac6 in questions_ids? True
# inserting qas with ids ['ee0a1e7c-70d1-4428-aa60-55741821b046', '22a4a0b8-ca13-41a3-be12-f36bad46bac6'] for split train
# paragraph['qas'] size: 2 for split train
# is 1b9a18cc-0bc8-4c38-8ba6-928a18984157 in questions_ids? True
# is a2f1a48a-4417-45bb-a6c6-2c518dbb2d2e in questions_ids? True
# inserting qas with ids ['1b9a18cc-0bc8-4c38-8ba6-928a18984157', 'a2f1a48a-4417-45bb-a6c6-2c518dbb2d2e'] for split train
# paragraph['qas'] size: 2 for split train
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is dff99e97-7c01-4218-81fc-f1d11f9a2213 in questions_ids? True
# is 09f2ecab-0fb9-46bc-a93e-8b4169362f41 in questions_ids? False
# inserting qas with ids ['dff99e97-7c01-4218-81fc-f1d11f9a2213'] for split train
# paragraph['qas'] size: 1 for split train
# is bdfbae28-6d50-4a59-9b10-047d11ddeaec in questions_ids? True
# is 5f8c30de-b2b0-40d6-b6e1-484d3d0bec7b in questions_ids? True
# inserting qas with ids ['bdfbae28-6d50-4a59-9b10-047d11ddeaec', '5f8c30de-b2b0-40d6-b6e1-484d3d0bec7b'] for split train
# paragraph['qas'] size: 2 for split train
# is 101743d7-6d0f-4802-8c9b-3ac58e1894c0 in questions_ids? False
# is bb9d6240-500d-4cd0-819c-367fbd2a6bd1 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is f1f4c8bb-eaf4-41f9-b53f-311efa23119a in questions_ids? True
# is fb09210b-9829-4c31-9cef-ffaae754262b in questions_ids? False
# inserting qas with ids ['f1f4c8bb-eaf4-41f9-b53f-311efa23119a'] for split train
# paragraph['qas'] size: 1 for split train
# is ea62e64e-3edc-4106-ac1b-e9041ef57bbb in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 6c245318-8480-4880-9563-52bdcae8f7c2 in questions_ids? False
# is d2309370-7971-4a79-9b59-0f6b5bc7e9c3 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is e6e72eaf-0c99-4790-bd1b-f8c32f98f16f in questions_ids? True
# is e5738943-857b-491b-99df-e4a911f56358 in questions_ids? True
# inserting qas with ids ['e6e72eaf-0c99-4790-bd1b-f8c32f98f16f', 'e5738943-857b-491b-99df-e4a911f56358'] for split train
# paragraph['qas'] size: 2 for split train
# is 9dedab11-341d-4e57-90af-c0f0911ebfcf in questions_ids? False
# is fc23cd2b-690a-47e6-b6ff-91402f627c0a in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 0d06484b-52a2-49c7-b1ea-f42ed1fdf868 in questions_ids? True
# is 0edae339-f11d-48c6-92f5-6937ff1f2ecc in questions_ids? True
# inserting qas with ids ['0d06484b-52a2-49c7-b1ea-f42ed1fdf868', '0edae339-f11d-48c6-92f5-6937ff1f2ecc'] for split train
# paragraph['qas'] size: 2 for split train
# is 2b597c39-d685-41f4-be9f-6a207de32fa7 in questions_ids? True
# is 7a60ea27-bc9f-4f8f-bb51-8718bd2f0139 in questions_ids? True
# inserting qas with ids ['2b597c39-d685-41f4-be9f-6a207de32fa7', '7a60ea27-bc9f-4f8f-bb51-8718bd2f0139'] for split train
# paragraph['qas'] size: 2 for split train
# is bc62a1f5-c892-4263-8c90-b17560a1326a in questions_ids? True
# is 1f80001c-62f8-434c-807c-16d65d85084e in questions_ids? False
# inserting qas with ids ['bc62a1f5-c892-4263-8c90-b17560a1326a'] for split train
# paragraph['qas'] size: 1 for split train
# is 71adc12a-a627-4df5-bb5d-dec6cfb65b07 in questions_ids? True
# is fecd19c5-2c80-4521-8eff-ff972bf0351c in questions_ids? True
# inserting qas with ids ['71adc12a-a627-4df5-bb5d-dec6cfb65b07', 'fecd19c5-2c80-4521-8eff-ff972bf0351c'] for split train
# paragraph['qas'] size: 2 for split train
# is 85d7e8fa-7bf6-42fe-9211-8f084dc45b53 in questions_ids? False
# is 9ed640dd-4e6f-43f4-b7c2-f9e87e9874e9 in questions_ids? True
# inserting qas with ids ['9ed640dd-4e6f-43f4-b7c2-f9e87e9874e9'] for split train
# paragraph['qas'] size: 1 for split train
# is 7b8b535e-58fd-46f9-aaa5-130820a54406 in questions_ids? True
# is 0fa4b89f-aeaa-4f1f-8282-525108ed467d in questions_ids? False
# inserting qas with ids ['7b8b535e-58fd-46f9-aaa5-130820a54406'] for split train
# paragraph['qas'] size: 1 for split train
# is e403e0e0-4473-460e-a595-f3c8b6c6a7c3 in questions_ids? True
# is b290569d-c379-4cf8-84b6-16b136c2eecb in questions_ids? False
# inserting qas with ids ['e403e0e0-4473-460e-a595-f3c8b6c6a7c3'] for split train
# paragraph['qas'] size: 1 for split train
# is 8094bc64-a712-4307-a9f1-cfdf7c92648f in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is abd90e91-e3d9-4ec8-a0d7-97d4cc098b3c in questions_ids? True
# is 7fce4656-92ee-4c6f-85d4-6d13dabdbff6 in questions_ids? True
# inserting qas with ids ['abd90e91-e3d9-4ec8-a0d7-97d4cc098b3c', '7fce4656-92ee-4c6f-85d4-6d13dabdbff6'] for split train
# paragraph['qas'] size: 2 for split train
# is 0a4c5d78-8369-49d8-8736-26379863af44 in questions_ids? True
# is 7c5fecc3-55a0-4341-85e1-4b9b879c1c05 in questions_ids? True
# inserting qas with ids ['0a4c5d78-8369-49d8-8736-26379863af44', '7c5fecc3-55a0-4341-85e1-4b9b879c1c05'] for split train
# paragraph['qas'] size: 2 for split train
# is ac42cbca-c9bf-4a0a-817c-876752656bad in questions_ids? False
# is c135a3b0-315e-4ff1-8a94-d73fad89146d in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 331353a8-61fb-421f-8d30-8afdda77d19a in questions_ids? True
# is bad64ac7-7ef6-4af1-a1a2-f949106731d5 in questions_ids? True
# inserting qas with ids ['331353a8-61fb-421f-8d30-8afdda77d19a', 'bad64ac7-7ef6-4af1-a1a2-f949106731d5'] for split train
# paragraph['qas'] size: 2 for split train
# is 80e19fa7-630a-4acf-8d4e-fd0d5cfd8b74 in questions_ids? True
# is 8d532bb8-dbf9-4851-be61-7f683d30875a in questions_ids? False
# inserting qas with ids ['80e19fa7-630a-4acf-8d4e-fd0d5cfd8b74'] for split train
# paragraph['qas'] size: 1 for split train
# is 5472a0cd-42c6-4c75-bc2e-4bffee0fe8d0 in questions_ids? False
# is 879d355c-e85d-498e-9aae-e8d6c0858c9b in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 46affaf2-edf5-44b4-b705-0fd22f5f75d1 in questions_ids? True
# is 8187f7ec-78ce-4eff-8432-3d0a068fd39b in questions_ids? True
# inserting qas with ids ['46affaf2-edf5-44b4-b705-0fd22f5f75d1', '8187f7ec-78ce-4eff-8432-3d0a068fd39b'] for split train
# paragraph['qas'] size: 2 for split train
# is 9f4efd09-4eb9-4b3b-b08c-87c7934807fd in questions_ids? False
# is bf83a676-3a04-4674-b221-a2c2f3b45db1 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 470516d8-9cc3-4fe3-89f4-44bd68973302 in questions_ids? True
# is 5731e8da-b355-439f-8c93-1b0febc6ba2d in questions_ids? False
# inserting qas with ids ['470516d8-9cc3-4fe3-89f4-44bd68973302'] for split train
# paragraph['qas'] size: 1 for split train
# is ce577482-3173-4c8f-8d2b-999aee2f3c74 in questions_ids? False
# is 57b19a8f-d8e3-41d1-85d4-0f75074b72e2 in questions_ids? True
# inserting qas with ids ['57b19a8f-d8e3-41d1-85d4-0f75074b72e2'] for split train
# paragraph['qas'] size: 1 for split train
# is f7e0b328-afce-49a2-ad52-4d587c125917 in questions_ids? False
# is d7ecfea1-9102-4f25-b67a-c6c892d27330 in questions_ids? True
# inserting qas with ids ['d7ecfea1-9102-4f25-b67a-c6c892d27330'] for split train
# paragraph['qas'] size: 1 for split train
# is 94d3b8b6-d78a-463b-90a8-0bb01a963c44 in questions_ids? False
# is 2b5d2ceb-5804-449a-b9b1-056a41839ad9 in questions_ids? True
# inserting qas with ids ['2b5d2ceb-5804-449a-b9b1-056a41839ad9'] for split train
# paragraph['qas'] size: 1 for split train
# is c82cb0e8-4fc2-4d9c-a1c1-90fe147dbc0c in questions_ids? True
# is c0c8c78e-633a-42f3-9c56-49ef0a80261b in questions_ids? True
# inserting qas with ids ['c82cb0e8-4fc2-4d9c-a1c1-90fe147dbc0c', 'c0c8c78e-633a-42f3-9c56-49ef0a80261b'] for split train
# paragraph['qas'] size: 2 for split train
# is 151068ac-b5a9-4d39-a8b6-e21439ecaac1 in questions_ids? True
# is 247f80a6-b1c3-475d-a0c2-57327e31fefb in questions_ids? False
# inserting qas with ids ['151068ac-b5a9-4d39-a8b6-e21439ecaac1'] for split train
# paragraph['qas'] size: 1 for split train
# is dddc5a9a-d3e6-4a72-b0cc-7a5b915d3f7c in questions_ids? False
# is 83b42cb0-6859-4f20-840d-8f6230e8d6a5 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 551accd5-2f2a-468b-8367-26abcbcc991e in questions_ids? True
# is d9191db3-13dd-4d60-9bd9-00bc51c7df99 in questions_ids? False
# inserting qas with ids ['551accd5-2f2a-468b-8367-26abcbcc991e'] for split train
# paragraph['qas'] size: 1 for split train
# is da205eb5-7a52-48f4-b9e4-4834b047f1ee in questions_ids? True
# inserting qas with ids ['da205eb5-7a52-48f4-b9e4-4834b047f1ee'] for split train
# paragraph['qas'] size: 1 for split train
# is f56b8f0a-eed4-40d4-aaa7-984dd8b9e4aa in questions_ids? False
# is a64f1df6-aea1-4677-946c-ed2a1cc94340 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 88452144-888a-4e2f-9d44-93604684d49d in questions_ids? False
# is fa82cd40-4862-4b26-993a-bc4f2d3885b5 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 86915f0c-030a-4ecf-a393-e5a26ab19a6a in questions_ids? True
# is 2ea4c2b7-5594-499c-a6a3-129bc5d6c95c in questions_ids? True
# inserting qas with ids ['86915f0c-030a-4ecf-a393-e5a26ab19a6a', '2ea4c2b7-5594-499c-a6a3-129bc5d6c95c'] for split train
# paragraph['qas'] size: 2 for split train
# is a471f47d-67ed-4f28-b111-3f926c1bf349 in questions_ids? False
# is 9e27c49c-fd56-4c5a-99be-2163994afcbc in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 00fd07a6-04b8-45ad-977d-74a51720deeb in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is d8b42838-4a86-4759-9207-4ea579aaf062 in questions_ids? False
# is c9689e08-08e4-4073-bc0f-b75716a73d5f in questions_ids? True
# inserting qas with ids ['c9689e08-08e4-4073-bc0f-b75716a73d5f'] for split train
# paragraph['qas'] size: 1 for split train
# is 581169ca-0718-459c-b498-87574960ae97 in questions_ids? True
# inserting qas with ids ['581169ca-0718-459c-b498-87574960ae97'] for split train
# paragraph['qas'] size: 1 for split train
# is dbc90034-6cbe-492f-981f-ec046c250fad in questions_ids? True
# is a935cb21-80a7-4674-a666-e8e62339b787 in questions_ids? False
# inserting qas with ids ['dbc90034-6cbe-492f-981f-ec046c250fad'] for split train
# paragraph['qas'] size: 1 for split train
# is 381227e2-43b1-4d1d-b6fc-0c3c738781af in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 1a34a4c3-f7e3-44ea-9a78-330241bad8b2 in questions_ids? True
# inserting qas with ids ['1a34a4c3-f7e3-44ea-9a78-330241bad8b2'] for split train
# paragraph['qas'] size: 1 for split train
# is 4b7b60a0-76f8-498c-9425-60b825952d97 in questions_ids? False
# is 3a2f9205-cca8-42cb-b744-39e2c4a96155 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is aed5e05d-7315-4051-ab0b-6b73d5319420 in questions_ids? True
# is 89e07e38-479e-43df-8267-80c5ebec8cd4 in questions_ids? True
# inserting qas with ids ['aed5e05d-7315-4051-ab0b-6b73d5319420', '89e07e38-479e-43df-8267-80c5ebec8cd4'] for split train
# paragraph['qas'] size: 2 for split train
# is 67520e6c-12b1-40d5-ba12-73acadff383f in questions_ids? True
# is 41ac320b-1a18-4c77-965a-90b7bf5af299 in questions_ids? True
# inserting qas with ids ['67520e6c-12b1-40d5-ba12-73acadff383f', '41ac320b-1a18-4c77-965a-90b7bf5af299'] for split train
# paragraph['qas'] size: 2 for split train
# is a55d1847-bb89-4227-9763-c75d96fd3867 in questions_ids? False
# is c6a9ed40-94d6-4d05-8f22-d8444b93e04b in questions_ids? True
# inserting qas with ids ['c6a9ed40-94d6-4d05-8f22-d8444b93e04b'] for split train
# paragraph['qas'] size: 1 for split train
# is e5b2c264-2fff-4ba5-addc-67b69ed393fd in questions_ids? False
# is b0b09387-5679-4ee6-b8ad-22b70496e2dc in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is c211b711-5ed3-452e-9402-472c5340708b in questions_ids? True
# is a55b39f0-9f4e-483d-bd1b-6f8f06993d04 in questions_ids? False
# inserting qas with ids ['c211b711-5ed3-452e-9402-472c5340708b'] for split train
# paragraph['qas'] size: 1 for split train
# is 95e117d5-2827-4902-8655-d831ea93b367 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 13e3d2e8-80c6-4287-9d06-5adb7e115b75 in questions_ids? True
# is 28aeb085-d146-4499-b9ab-2f78e84255f3 in questions_ids? True
# inserting qas with ids ['13e3d2e8-80c6-4287-9d06-5adb7e115b75', '28aeb085-d146-4499-b9ab-2f78e84255f3'] for split train
# paragraph['qas'] size: 2 for split train
# is 5b1d10b3-81a4-45e0-8f10-78ade0a1c5a6 in questions_ids? True
# is d64ec2d4-ec3f-42d2-b2d4-e80a4bd95b6c in questions_ids? False
# inserting qas with ids ['5b1d10b3-81a4-45e0-8f10-78ade0a1c5a6'] for split train
# paragraph['qas'] size: 1 for split train
# is 1c909842-ae69-4041-a167-8dd117ff5c8d in questions_ids? True
# is bf57d4b2-0985-4900-8ea1-d032e4db5c41 in questions_ids? False
# inserting qas with ids ['1c909842-ae69-4041-a167-8dd117ff5c8d'] for split train
# paragraph['qas'] size: 1 for split train
# is b5ba6c35-a1e6-4ca2-9570-a35f76985767 in questions_ids? False
# is 8bcbac5b-df79-4a02-857f-f87611e34ad4 in questions_ids? True
# inserting qas with ids ['8bcbac5b-df79-4a02-857f-f87611e34ad4'] for split train
# paragraph['qas'] size: 1 for split train
# is 3939814e-ae59-4323-aab5-8ce174f54268 in questions_ids? False
# is ca780216-14e4-4778-970d-37a686c17460 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 2509aca0-4b21-4838-9625-e29a595984a7 in questions_ids? True
# is b1f6832f-0ca0-439d-a1cc-694b2f648031 in questions_ids? True
# inserting qas with ids ['2509aca0-4b21-4838-9625-e29a595984a7', 'b1f6832f-0ca0-439d-a1cc-694b2f648031'] for split train
# paragraph['qas'] size: 2 for split train
# is 60ba3699-968d-40ab-9b4b-515ffa5095dc in questions_ids? False
# is 1cd5cdb1-cb10-4c43-ba02-affe23a65986 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 4f300f30-c021-4fa9-996d-14a4d99d2792 in questions_ids? True
# is c31c8a02-7cbf-459c-b8d4-d1d858281212 in questions_ids? False
# inserting qas with ids ['4f300f30-c021-4fa9-996d-14a4d99d2792'] for split train
# paragraph['qas'] size: 1 for split train
# is 287b2b9b-0b37-4662-b8b7-171e2658ef6d in questions_ids? True
# is cb5a5a47-bae3-46ce-a133-36e838a557e3 in questions_ids? False
# inserting qas with ids ['287b2b9b-0b37-4662-b8b7-171e2658ef6d'] for split train
# paragraph['qas'] size: 1 for split train
# is a3395b3a-1a8c-4bb5-a572-8c0a48f40434 in questions_ids? True
# is 5f186355-f8aa-4ed1-9bf4-2257e2c45080 in questions_ids? True
# inserting qas with ids ['a3395b3a-1a8c-4bb5-a572-8c0a48f40434', '5f186355-f8aa-4ed1-9bf4-2257e2c45080'] for split train
# paragraph['qas'] size: 2 for split train
# is b52f6435-446c-4d63-b970-3eeca0d85572 in questions_ids? False
# is aefab8cb-659d-4222-b59a-1c93a5caf05f in questions_ids? True
# inserting qas with ids ['aefab8cb-659d-4222-b59a-1c93a5caf05f'] for split train
# paragraph['qas'] size: 1 for split train
# is 2f458772-8882-4342-80f4-141d31bab8f9 in questions_ids? False
# is 02dd2ec0-a7ed-4912-a366-e39f1c77991a in questions_ids? True
# inserting qas with ids ['02dd2ec0-a7ed-4912-a366-e39f1c77991a'] for split train
# paragraph['qas'] size: 1 for split train
# is 716abf22-72a9-4a5e-9507-5b825ec29441 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 06a4a191-b3c5-4658-b80b-cb25525027f3 in questions_ids? False
# is a25961e0-b1a7-4f54-95d5-8d2e004cbeee in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 396da80d-ced5-40b3-8355-8e0d53ebe5b6 in questions_ids? True
# is c65f840b-ac17-47cd-ae54-0cc5b344862a in questions_ids? True
# inserting qas with ids ['396da80d-ced5-40b3-8355-8e0d53ebe5b6', 'c65f840b-ac17-47cd-ae54-0cc5b344862a'] for split train
# paragraph['qas'] size: 2 for split train
# is 2e29dd1b-6979-40f6-b58b-87e674d2d8cd in questions_ids? True
# is f8349e4b-620b-4dbb-afab-5ea113b10262 in questions_ids? False
# inserting qas with ids ['2e29dd1b-6979-40f6-b58b-87e674d2d8cd'] for split train
# paragraph['qas'] size: 1 for split train
# is d8ccd403-9640-4d05-a207-daf464d3b6fa in questions_ids? False
# is ddb12330-0669-4005-98c4-e3e993c89cd6 in questions_ids? True
# inserting qas with ids ['ddb12330-0669-4005-98c4-e3e993c89cd6'] for split train
# paragraph['qas'] size: 1 for split train
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 500fb50e-3d6a-4374-89ce-3430fad2e2ad in questions_ids? False
# is 5cc0f727-f801-4436-8686-9a5c5a452c5f in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is b95b0fe0-c2bf-4086-a2c5-ebb40e46f3d5 in questions_ids? False
# is ff0485f0-e187-4a77-b54f-e40b65d0eccf in questions_ids? True
# inserting qas with ids ['ff0485f0-e187-4a77-b54f-e40b65d0eccf'] for split train
# paragraph['qas'] size: 1 for split train
# is 62ff4910-2ca1-44e1-b3e6-6b4468e4d4a7 in questions_ids? True
# is 13ed7ecd-5766-479d-aef2-c99023885297 in questions_ids? True
# inserting qas with ids ['62ff4910-2ca1-44e1-b3e6-6b4468e4d4a7', '13ed7ecd-5766-479d-aef2-c99023885297'] for split train
# paragraph['qas'] size: 2 for split train
# is 09ce1cc5-b088-4ab5-90ff-ac331e03647a in questions_ids? True
# is 94137953-1d6f-42c9-b53b-71468c68960b in questions_ids? True
# inserting qas with ids ['09ce1cc5-b088-4ab5-90ff-ac331e03647a', '94137953-1d6f-42c9-b53b-71468c68960b'] for split train
# paragraph['qas'] size: 2 for split train
# is 62c77181-96d5-4749-a91b-650ca0818997 in questions_ids? True
# is 22db6bd1-f7d4-418c-803c-81298cdb6d7f in questions_ids? True
# inserting qas with ids ['62c77181-96d5-4749-a91b-650ca0818997', '22db6bd1-f7d4-418c-803c-81298cdb6d7f'] for split train
# paragraph['qas'] size: 2 for split train
# is 552922e3-9a90-46af-a25f-e5107db4a263 in questions_ids? False
# is 5b9831ca-d135-48d2-8712-51813b687086 in questions_ids? True
# inserting qas with ids ['5b9831ca-d135-48d2-8712-51813b687086'] for split train
# paragraph['qas'] size: 1 for split train
# is 6a30bdea-935b-4229-acb4-004033f91f6a in questions_ids? True
# is 8b5815b2-b125-4ca0-b985-05e4c25a5a17 in questions_ids? True
# inserting qas with ids ['6a30bdea-935b-4229-acb4-004033f91f6a', '8b5815b2-b125-4ca0-b985-05e4c25a5a17'] for split train
# paragraph['qas'] size: 2 for split train
# is 32c30893-261f-46e6-8476-3d0f0ce050dd in questions_ids? False
# is 0946162b-996e-4afc-ae4f-bf9fd6e962ef in questions_ids? True
# inserting qas with ids ['0946162b-996e-4afc-ae4f-bf9fd6e962ef'] for split train
# paragraph['qas'] size: 1 for split train
# is e1f6bfb8-e2a4-45e5-a755-4cc73a501bfc in questions_ids? False
# is 58557e5a-c5f3-48fc-ac1e-884226878218 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is aec9d0a7-3d56-4b10-97cc-eb1ce1fefab4 in questions_ids? True
# is cafeffcd-84d0-4b69-99e2-3fe92b41a8c3 in questions_ids? True
# is 16f4d73c-0c19-4464-8fac-8ee83c735200 in questions_ids? False
# inserting qas with ids ['aec9d0a7-3d56-4b10-97cc-eb1ce1fefab4', 'cafeffcd-84d0-4b69-99e2-3fe92b41a8c3'] for split train
# paragraph['qas'] size: 2 for split train
# is c62d3807-79ad-43f7-9ad0-3992bf3b012d in questions_ids? True
# is de31e1fc-37ae-43e6-bc80-a978c913fa30 in questions_ids? True
# inserting qas with ids ['c62d3807-79ad-43f7-9ad0-3992bf3b012d', 'de31e1fc-37ae-43e6-bc80-a978c913fa30'] for split train
# paragraph['qas'] size: 2 for split train
# is 35babe37-f99d-425a-a138-e84f864b8f32 in questions_ids? False
# is ccdcf386-fdfa-4bd3-bcaf-fd1327143ea3 in questions_ids? True
# inserting qas with ids ['ccdcf386-fdfa-4bd3-bcaf-fd1327143ea3'] for split train
# paragraph['qas'] size: 1 for split train
# is 2137cfa8-9d7c-4c94-acd2-be741c6c64b5 in questions_ids? True
# is bceca970-8607-46c2-be65-93035aa8e745 in questions_ids? True
# inserting qas with ids ['2137cfa8-9d7c-4c94-acd2-be741c6c64b5', 'bceca970-8607-46c2-be65-93035aa8e745'] for split train
# paragraph['qas'] size: 2 for split train
# is ad5fba47-1f38-433a-9726-8656ba08fc45 in questions_ids? True
# is a0e568eb-180e-4865-bd5c-6b02c9f1f3c5 in questions_ids? False
# inserting qas with ids ['ad5fba47-1f38-433a-9726-8656ba08fc45'] for split train
# paragraph['qas'] size: 1 for split train
# is 587d1f49-82ff-4cb0-a13f-5d5356bd6a09 in questions_ids? False
# is b86a9aa1-3cfc-4985-84a2-f2c5d1825a7e in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is ce3e30d7-3147-48ae-9339-13f09352367c in questions_ids? True
# is 35a9b388-dad5-4d16-9d60-e912a6b2c5e6 in questions_ids? False
# inserting qas with ids ['ce3e30d7-3147-48ae-9339-13f09352367c'] for split train
# paragraph['qas'] size: 1 for split train
# is 5163ebf6-24d1-45d2-94e1-ce785af6bfba in questions_ids? False
# is de582915-6fbc-4ea5-b15f-41a0146ad37e in questions_ids? True
# inserting qas with ids ['de582915-6fbc-4ea5-b15f-41a0146ad37e'] for split train
# paragraph['qas'] size: 1 for split train
# is 302d621b-8dae-4260-84b5-8e4dd73c7333 in questions_ids? True
# is e9c6ccb9-f3c0-45dd-864b-24d9c06d95bf in questions_ids? True
# inserting qas with ids ['302d621b-8dae-4260-84b5-8e4dd73c7333', 'e9c6ccb9-f3c0-45dd-864b-24d9c06d95bf'] for split train
# paragraph['qas'] size: 2 for split train
# is 1d6d1adc-cb96-4c5f-911d-e3e628d8efe5 in questions_ids? False
# is 6030a875-6284-40d0-992d-08374824f2c2 in questions_ids? False
# is 9e38330a-ce6b-4c6c-8f8a-60987f42cacb in questions_ids? True
# is 4a966cbd-732e-47e7-a674-3ba79c536ceb in questions_ids? False
# is 0e7836dd-3e68-430d-acf1-b30e5e9fee4a in questions_ids? True
# inserting qas with ids ['9e38330a-ce6b-4c6c-8f8a-60987f42cacb', '0e7836dd-3e68-430d-acf1-b30e5e9fee4a'] for split train
# paragraph['qas'] size: 2 for split train
# is 71c8b337-b4c9-4c42-a398-f200a433999e in questions_ids? True
# is e63119f4-8c6b-41cc-8747-b19f334e7b98 in questions_ids? False
# inserting qas with ids ['71c8b337-b4c9-4c42-a398-f200a433999e'] for split train
# paragraph['qas'] size: 1 for split train
# is 5650e32d-c869-48ce-a46c-500c149294e3 in questions_ids? True
# inserting qas with ids ['5650e32d-c869-48ce-a46c-500c149294e3'] for split train
# paragraph['qas'] size: 1 for split train
# is 11e0bec7-eb79-4ffa-af31-b7f86b009dea in questions_ids? True
# is a287e3b2-e6b9-4726-bb83-4712a9c7aecd in questions_ids? False
# inserting qas with ids ['11e0bec7-eb79-4ffa-af31-b7f86b009dea'] for split train
# paragraph['qas'] size: 1 for split train
# is 6a2062bd-0b9a-44e5-bd7c-cf54b95ed40f in questions_ids? False
# is aeb7636f-1f6b-425f-aa5f-fd9e858b1045 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 257ad1da-b941-47e7-9cd8-2653ae57a144 in questions_ids? False
# is 316cd0d5-de1f-4b62-979d-a0f4629b958a in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 22131e12-cc59-4801-be4c-135f398bb496 in questions_ids? True
# is e12386cc-f3ec-48ee-b385-e6ed58b40798 in questions_ids? True
# inserting qas with ids ['22131e12-cc59-4801-be4c-135f398bb496', 'e12386cc-f3ec-48ee-b385-e6ed58b40798'] for split train
# paragraph['qas'] size: 2 for split train
# is ccc53a2c-ded7-43b5-8aeb-b7903089d48e in questions_ids? True
# is 4bd80bcb-6a82-4c56-82ed-fe6c5a0a8768 in questions_ids? True
# inserting qas with ids ['ccc53a2c-ded7-43b5-8aeb-b7903089d48e', '4bd80bcb-6a82-4c56-82ed-fe6c5a0a8768'] for split train
# paragraph['qas'] size: 2 for split train
# is 7f943cc8-4587-4679-a9dc-770c04051dab in questions_ids? False
# is f42ff2b5-375c-4b19-b6fa-e04394da80aa in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is c3f3fd3f-6ccf-4786-b4f9-1baf62e045f1 in questions_ids? True
# is dbe1085e-561a-454f-b54f-3c3c89daedd6 in questions_ids? False
# inserting qas with ids ['c3f3fd3f-6ccf-4786-b4f9-1baf62e045f1'] for split train
# paragraph['qas'] size: 1 for split train
# is 680fecaf-1b4f-4d38-afcc-16f944671e1c in questions_ids? False
# is 48b4c398-6de1-4405-a016-6b5d4fe330ae in questions_ids? True
# inserting qas with ids ['48b4c398-6de1-4405-a016-6b5d4fe330ae'] for split train
# paragraph['qas'] size: 1 for split train
# is d1371b78-207f-4024-97fa-7f3b9238addc in questions_ids? False
# is 92621c99-b569-4ba6-bfef-bc32f1c4efe0 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 0746f593-f90a-438a-a28e-6051c3e4cad7 in questions_ids? True
# is 4923b25d-3a20-4f6a-bd4a-3ec1a786b9d6 in questions_ids? True
# inserting qas with ids ['0746f593-f90a-438a-a28e-6051c3e4cad7', '4923b25d-3a20-4f6a-bd4a-3ec1a786b9d6'] for split train
# paragraph['qas'] size: 2 for split train
# is 4c27f5d3-1830-4a9d-a0f1-63f2fad611ae in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is a7071ef7-0e84-4a80-854c-7d92e7c89195 in questions_ids? False
# is 56fdb356-8fe1-4796-bbee-50a7b0188078 in questions_ids? True
# inserting qas with ids ['56fdb356-8fe1-4796-bbee-50a7b0188078'] for split train
# paragraph['qas'] size: 1 for split train
# is 9b250abb-b451-4242-8148-fc423e04ba4d in questions_ids? True
# is d5e49260-d91a-48fa-93a2-ce915693c85d in questions_ids? False
# inserting qas with ids ['9b250abb-b451-4242-8148-fc423e04ba4d'] for split train
# paragraph['qas'] size: 1 for split train
# is 9f2f49f2-2ba6-4f41-940f-825c58c3bc64 in questions_ids? True
# is 2fe48545-221f-480a-8fd8-3a56f09285aa in questions_ids? True
# inserting qas with ids ['9f2f49f2-2ba6-4f41-940f-825c58c3bc64', '2fe48545-221f-480a-8fd8-3a56f09285aa'] for split train
# paragraph['qas'] size: 2 for split train
# is bd452082-b134-428e-9438-382dfbe87798 in questions_ids? False
# is 37ce7875-77c4-491e-86ba-cb572b7e0960 in questions_ids? True
# inserting qas with ids ['37ce7875-77c4-491e-86ba-cb572b7e0960'] for split train
# paragraph['qas'] size: 1 for split train
# is 1944639d-fd37-4b8e-bd40-d45d0b4a7c09 in questions_ids? True
# is 5f47017d-40b0-43b7-bf17-9c15f5bd2730 in questions_ids? False
# inserting qas with ids ['1944639d-fd37-4b8e-bd40-d45d0b4a7c09'] for split train
# paragraph['qas'] size: 1 for split train
# is bd64297a-a4b9-4ada-af89-bae42e5709c8 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is a7bc29bc-039b-49c0-a95c-61945c9b2527 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is b0837960-cdac-49ea-aab4-b7919560ef65 in questions_ids? False
# is cbb218c2-f060-40e3-a9f8-4d2b2c512e8b in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 870f5b19-d5a6-40dd-ab0f-bd51e555d699 in questions_ids? True
# is 5bded59e-a04a-49c0-be98-78fe460cce4a in questions_ids? True
# inserting qas with ids ['870f5b19-d5a6-40dd-ab0f-bd51e555d699', '5bded59e-a04a-49c0-be98-78fe460cce4a'] for split train
# paragraph['qas'] size: 2 for split train
# is 2ede3c19-435a-4c4b-9fa4-479f6c220fc2 in questions_ids? False
# is 5d0ee6ce-118c-44b9-ba32-cb8278fb2126 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is 56461714-59ed-49f7-a872-1d7f0642e519 in questions_ids? False
# inserting qas with ids [] for split train
# paragraph['qas'] size: 0 for split train
# is b30ea7f3-f021-4967-87d1-351f92382cc6 in questions_ids? True
# ...
# is 34b17fac-162d-4c2d-b0c9-ee8638b67274 in questions_ids? True
# inserting qas with ids ['dc369835-34ea-4464-a960-30441c894b12', '34b17fac-162d-4c2d-b0c9-ee8638b67274'] for split test
# paragraph['qas'] size: 2 for split test
# is 97b2ac06-5ff7-4d9f-b3ee-6fba3a37f137 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is fb74f8c5-550c-4dc5-9967-88398e944ebb in questions_ids? False
# is 3c88469f-2aee-448d-8275-b5994c413816 in questions_ids? True
# inserting qas with ids ['3c88469f-2aee-448d-8275-b5994c413816'] for split test
# paragraph['qas'] size: 1 for split test
# is 705aec45-dfb4-4286-8fff-9eb3876f5b41 in questions_ids? True
# inserting qas with ids ['705aec45-dfb4-4286-8fff-9eb3876f5b41'] for split test
# paragraph['qas'] size: 1 for split test
# is 37501dd1-0da0-4249-850f-78a169b93c24 in questions_ids? True
# is a533e5a7-f0df-4e07-b833-ebcfb3892bb1 in questions_ids? False
# inserting qas with ids ['37501dd1-0da0-4249-850f-78a169b93c24'] for split test
# paragraph['qas'] size: 1 for split test
# is 0b22a132-0a2f-4879-93bb-44012389e49f in questions_ids? False
# is e1edf274-165c-4c7a-9831-215043357357 in questions_ids? True
# inserting qas with ids ['e1edf274-165c-4c7a-9831-215043357357'] for split test
# paragraph['qas'] size: 1 for split test
# is c7ac4b7d-ecd5-4555-8496-9a072d75448a in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 91363141-b552-4893-8df3-579aa30778a7 in questions_ids? True
# inserting qas with ids ['91363141-b552-4893-8df3-579aa30778a7'] for split test
# paragraph['qas'] size: 1 for split test
# is 398c8a5c-985b-4327-b3b8-3aa30c1631dc in questions_ids? True
# inserting qas with ids ['398c8a5c-985b-4327-b3b8-3aa30c1631dc'] for split test
# paragraph['qas'] size: 1 for split test
# is b456458e-8dd7-456e-ad47-8b9fd21191a9 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 3004c7ea-9840-4365-a872-d133aa01e5a4 in questions_ids? True
# is 1437c6f7-e191-496f-9166-2741afdce483 in questions_ids? True
# inserting qas with ids ['3004c7ea-9840-4365-a872-d133aa01e5a4', '1437c6f7-e191-496f-9166-2741afdce483'] for split test
# paragraph['qas'] size: 2 for split test
# is 29dbb6c1-ea91-4f2a-932b-56b2015b062d in questions_ids? True
# is 986fdaf7-f9d3-4646-a58a-ca7cf2c43917 in questions_ids? True
# is 815c770d-6396-4d36-be17-f1de1138d77d in questions_ids? True
# inserting qas with ids ['29dbb6c1-ea91-4f2a-932b-56b2015b062d', '986fdaf7-f9d3-4646-a58a-ca7cf2c43917', '815c770d-6396-4d36-be17-f1de1138d77d'] for split test
# paragraph['qas'] size: 3 for split test
# is 8a57c377-c5e7-4ae7-a779-55066222b7e4 in questions_ids? False
# is c3cf7564-1728-4454-be31-dd5877284163 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 3ffef7c3-bd8c-41e7-abcb-c74b4d5cb65d in questions_ids? False
# is 47dffef7-2478-452e-a2c5-f02ec8d4178f in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 9c79a273-81c2-4b51-8f3f-46cb3fadf231 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 3d970c40-3070-4ec8-bd79-e7683437fae2 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is b5ffca54-1600-40e6-b2bc-9c2e00b88928 in questions_ids? False
# is e646276a-4bd6-46b5-bb6e-56c4f03a02f0 in questions_ids? True
# inserting qas with ids ['e646276a-4bd6-46b5-bb6e-56c4f03a02f0'] for split test
# paragraph['qas'] size: 1 for split test
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 298ada37-cca2-4e0e-9073-30800e07846c in questions_ids? True
# is e6edee45-63b4-4788-9030-40c198f9bc02 in questions_ids? False
# inserting qas with ids ['298ada37-cca2-4e0e-9073-30800e07846c'] for split test
# paragraph['qas'] size: 1 for split test
# is 956b08d0-813e-4d78-b019-1291bb8bed2e in questions_ids? True
# is 286e80f6-ce61-4263-9139-2849d9a68e07 in questions_ids? False
# inserting qas with ids ['956b08d0-813e-4d78-b019-1291bb8bed2e'] for split test
# paragraph['qas'] size: 1 for split test
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 42e91dd1-d89f-4132-b482-d0e44aa0478c in questions_ids? True
# is b884ca33-120c-4075-a20b-594be6ab2a21 in questions_ids? True
# inserting qas with ids ['42e91dd1-d89f-4132-b482-d0e44aa0478c', 'b884ca33-120c-4075-a20b-594be6ab2a21'] for split test
# paragraph['qas'] size: 2 for split test
# is 9826b807-e431-4991-9010-e10614af5919 in questions_ids? False
# is e9434eb6-8718-4552-add8-18bda1918085 in questions_ids? True
# inserting qas with ids ['e9434eb6-8718-4552-add8-18bda1918085'] for split test
# paragraph['qas'] size: 1 for split test
# is 89650702-8543-4be6-9fe8-d868103afd2e in questions_ids? True
# is f24b2ee5-5ff0-4cf4-8372-0e12e3531e80 in questions_ids? True
# inserting qas with ids ['89650702-8543-4be6-9fe8-d868103afd2e', 'f24b2ee5-5ff0-4cf4-8372-0e12e3531e80'] for split test
# paragraph['qas'] size: 2 for split test
# is 66021793-f0e1-41dd-8571-4f2bcd3eb1f9 in questions_ids? True
# is 3e175a99-3dc8-45be-bda3-9d8ff8656e37 in questions_ids? False
# inserting qas with ids ['66021793-f0e1-41dd-8571-4f2bcd3eb1f9'] for split test
# paragraph['qas'] size: 1 for split test
# is 17b99bd1-5f3e-4687-88eb-9860331ba3cf in questions_ids? False
# is 44ed24f3-2ba4-405e-951a-a383d6d7437b in questions_ids? True
# inserting qas with ids ['44ed24f3-2ba4-405e-951a-a383d6d7437b'] for split test
# paragraph['qas'] size: 1 for split test
# is 999d59ee-a021-4c17-9172-329a6597e4be in questions_ids? False
# is b5727112-2caf-4444-b85f-70e7e324d1f7 in questions_ids? True
# inserting qas with ids ['b5727112-2caf-4444-b85f-70e7e324d1f7'] for split test
# paragraph['qas'] size: 1 for split test
# is ec54f840-9d86-4670-82ae-8a627d0ebbaf in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 2eec284c-da76-4664-a4d4-a0b3997d3644 in questions_ids? True
# is a37f1045-aafd-47f7-bea6-1c35e756e5a7 in questions_ids? False
# inserting qas with ids ['2eec284c-da76-4664-a4d4-a0b3997d3644'] for split test
# paragraph['qas'] size: 1 for split test
# is 71fbe45e-dc70-4d21-9940-03c0b1e6ab4f in questions_ids? False
# is a18e84f8-b8e8-43df-abdf-5bc7deeb0d87 in questions_ids? True
# inserting qas with ids ['a18e84f8-b8e8-43df-abdf-5bc7deeb0d87'] for split test
# paragraph['qas'] size: 1 for split test
# is f576ac40-7742-4da7-ae02-a6dbd6c7ca5d in questions_ids? False
# is 9b7bdc9a-8855-4891-80ab-e89a9afd1dd6 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 47717b0a-3be7-4d5b-9013-2afebf8d043b in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 636405d0-ac7c-4f6b-bcbb-e8c2eb0d619a in questions_ids? True
# is 6e9f6f1c-3b7c-4609-8e74-67c463fc8c53 in questions_ids? False
# inserting qas with ids ['636405d0-ac7c-4f6b-bcbb-e8c2eb0d619a'] for split test
# paragraph['qas'] size: 1 for split test
# is 14550350-5b1f-446b-a47d-6f8672da39a4 in questions_ids? True
# inserting qas with ids ['14550350-5b1f-446b-a47d-6f8672da39a4'] for split test
# paragraph['qas'] size: 1 for split test
# is 103a523d-3b18-46cd-a72c-66a58d8118f1 in questions_ids? False
# is 1725fa12-c0ce-4bee-b4e9-4c75c25d40d0 in questions_ids? True
# inserting qas with ids ['1725fa12-c0ce-4bee-b4e9-4c75c25d40d0'] for split test
# paragraph['qas'] size: 1 for split test
# is 1463ae2d-7d43-498c-9381-b0824b2b77ae in questions_ids? True
# inserting qas with ids ['1463ae2d-7d43-498c-9381-b0824b2b77ae'] for split test
# paragraph['qas'] size: 1 for split test
# is 16fd3809-d5e4-4468-af6d-1bd690c2b395 in questions_ids? True
# is 0b7593c8-a51d-4181-9925-1c4923887da0 in questions_ids? False
# inserting qas with ids ['16fd3809-d5e4-4468-af6d-1bd690c2b395'] for split test
# paragraph['qas'] size: 1 for split test
# is f8fc1e8e-fe69-44ec-9be3-5535c1fdbd54 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is f0dbcc8b-da8f-4c2d-adb9-2d88eabd3832 in questions_ids? False
# is 54dc5f54-3221-46d5-98e1-6bd77b285690 in questions_ids? True
# inserting qas with ids ['54dc5f54-3221-46d5-98e1-6bd77b285690'] for split test
# paragraph['qas'] size: 1 for split test
# is 94156e7b-a59f-4431-983c-393f0e88fa48 in questions_ids? False
# is 3fbb7e79-e8d0-42f7-8d29-a4fbc2be1550 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 75c78ec5-139a-40a9-80ad-232fd95dce99 in questions_ids? True
# is 3130f927-51b1-459f-99b9-dc34e80b3607 in questions_ids? True
# inserting qas with ids ['75c78ec5-139a-40a9-80ad-232fd95dce99', '3130f927-51b1-459f-99b9-dc34e80b3607'] for split test
# paragraph['qas'] size: 2 for split test
# is 9d67e73b-9d8c-43ee-b8a8-78a7e162d2fc in questions_ids? True
# is 36686a21-a4f2-43e7-9cf9-2716675f5a24 in questions_ids? True
# inserting qas with ids ['9d67e73b-9d8c-43ee-b8a8-78a7e162d2fc', '36686a21-a4f2-43e7-9cf9-2716675f5a24'] for split test
# paragraph['qas'] size: 2 for split test
# is 441f56a1-81bb-4683-9793-eaef5a2312a6 in questions_ids? False
# is 7e0c2822-1fd7-4feb-9ccc-eb116e64d03b in questions_ids? True
# inserting qas with ids ['7e0c2822-1fd7-4feb-9ccc-eb116e64d03b'] for split test
# paragraph['qas'] size: 1 for split test
# is 01f93a44-0ec8-46f1-bbcd-2069d79db698 in questions_ids? True
# inserting qas with ids ['01f93a44-0ec8-46f1-bbcd-2069d79db698'] for split test
# paragraph['qas'] size: 1 for split test
# is 8d5be9d7-55c6-4057-99fb-e02af003e2f2 in questions_ids? True
# is b272780d-39cb-4943-91c6-66be97f20a99 in questions_ids? False
# inserting qas with ids ['8d5be9d7-55c6-4057-99fb-e02af003e2f2'] for split test
# paragraph['qas'] size: 1 for split test
# is c6a21ec3-347f-43b6-9315-293786aa43e7 in questions_ids? True
# is 2b99316f-cba3-4161-ab79-238479e8240e in questions_ids? True
# inserting qas with ids ['c6a21ec3-347f-43b6-9315-293786aa43e7', '2b99316f-cba3-4161-ab79-238479e8240e'] for split test
# paragraph['qas'] size: 2 for split test
# is 8a58b7f3-81a2-4e40-b849-63e47c1b575b in questions_ids? True
# inserting qas with ids ['8a58b7f3-81a2-4e40-b849-63e47c1b575b'] for split test
# paragraph['qas'] size: 1 for split test
# is 6cf15d4c-0107-4572-9cb3-b9a8f36b9783 in questions_ids? True
# is 04d8b411-6aff-40e9-8348-67e753483e50 in questions_ids? False
# inserting qas with ids ['6cf15d4c-0107-4572-9cb3-b9a8f36b9783'] for split test
# paragraph['qas'] size: 1 for split test
# is 2563c8ee-74b8-4de4-80f7-5398d35f5edf in questions_ids? True
# is b77814c1-e6a4-4b2c-8b65-f84ce9df2cac in questions_ids? True
# inserting qas with ids ['2563c8ee-74b8-4de4-80f7-5398d35f5edf', 'b77814c1-e6a4-4b2c-8b65-f84ce9df2cac'] for split test
# paragraph['qas'] size: 2 for split test
# is 62a11c61-3e13-466d-8f87-5d06180b4c18 in questions_ids? True
# is e7d5da97-7cec-466c-9f7c-1d48d90298c0 in questions_ids? False
# inserting qas with ids ['62a11c61-3e13-466d-8f87-5d06180b4c18'] for split test
# paragraph['qas'] size: 1 for split test
# is 43177e49-7099-4da1-a186-06ccdc70ff65 in questions_ids? False
# is 289c582e-1507-461e-94d8-ab27f1a73bce in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 70d5da1f-23f6-46bd-8ccb-4411dff54a85 in questions_ids? True
# is 33e0bf08-6f17-4449-8fdd-d953db8bcc3a in questions_ids? True
# inserting qas with ids ['70d5da1f-23f6-46bd-8ccb-4411dff54a85', '33e0bf08-6f17-4449-8fdd-d953db8bcc3a'] for split test
# paragraph['qas'] size: 2 for split test
# is a2e982c7-837a-4727-8ef0-39eb9af8131d in questions_ids? True
# is 1b126e5e-51a6-434f-b927-d10390c6ffac in questions_ids? False
# inserting qas with ids ['a2e982c7-837a-4727-8ef0-39eb9af8131d'] for split test
# paragraph['qas'] size: 1 for split test
# is 8e58838c-a0ee-42a6-9f52-0f1bcc9e202c in questions_ids? False
# is fea3e0e6-dea9-4554-b171-a2813ba8de80 in questions_ids? True
# inserting qas with ids ['fea3e0e6-dea9-4554-b171-a2813ba8de80'] for split test
# paragraph['qas'] size: 1 for split test
# is f0943b3c-02af-4ec2-ae7b-b3b5e0012db3 in questions_ids? False
# is 7d4b4b80-a32d-446f-99e5-92abab70ac52 in questions_ids? True
# inserting qas with ids ['7d4b4b80-a32d-446f-99e5-92abab70ac52'] for split test
# paragraph['qas'] size: 1 for split test
# is 33d45399-85b3-49f0-a9d4-e273fd3b08cd in questions_ids? False
# is 6c1d0e58-8c21-492b-9bf5-9ad8f41ba4f1 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 8582f3ab-ca20-4566-934c-295107dd948d in questions_ids? False
# is 16be2ae5-10b9-47ee-b995-e89497a77351 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 71005d2f-bd01-4002-b85c-9848fc943849 in questions_ids? True
# is 34c45285-7756-417b-91f0-b1cf38e78b3c in questions_ids? False
# inserting qas with ids ['71005d2f-bd01-4002-b85c-9848fc943849'] for split test
# paragraph['qas'] size: 1 for split test
# is 53ee368a-362a-496d-89fc-4460cb4d2d1e in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is b8a714a4-406f-4360-90b7-1a5dd288262e in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 140c555d-6a5c-46ba-a74f-5dba0f224923 in questions_ids? True
# inserting qas with ids ['140c555d-6a5c-46ba-a74f-5dba0f224923'] for split test
# paragraph['qas'] size: 1 for split test
# is e32ade48-988d-4e3f-b6ea-c80dc623aea6 in questions_ids? True
# is 35e0aa8b-e7dd-4e74-b20e-c616addfe5b8 in questions_ids? True
# inserting qas with ids ['e32ade48-988d-4e3f-b6ea-c80dc623aea6', '35e0aa8b-e7dd-4e74-b20e-c616addfe5b8'] for split test
# paragraph['qas'] size: 2 for split test
# is 2f600e39-a521-4288-bb67-2ba39e3b9af3 in questions_ids? True
# inserting qas with ids ['2f600e39-a521-4288-bb67-2ba39e3b9af3'] for split test
# paragraph['qas'] size: 1 for split test
# is 5eadfab5-6a6b-42a3-bbde-42f1114acfa3 in questions_ids? True
# is fb09b7d5-8db5-4a0e-a85c-a235f54ee79c in questions_ids? False
# inserting qas with ids ['5eadfab5-6a6b-42a3-bbde-42f1114acfa3'] for split test
# paragraph['qas'] size: 1 for split test
# is 4ef08bca-c744-4e57-8f71-9196e923bf42 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 7a5a6bbf-46c6-45aa-902b-008b9f0559e3 in questions_ids? True
# is 85135717-e075-490f-8a3f-d13784a8f2e5 in questions_ids? False
# inserting qas with ids ['7a5a6bbf-46c6-45aa-902b-008b9f0559e3'] for split test
# paragraph['qas'] size: 1 for split test
# is 4cd204e6-d146-4779-83d9-0d325b8cb212 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 480a2490-30aa-46ce-aa21-4360fb7f9105 in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test
# is 13a46eb1-5461-465d-8980-62f633929539 in questions_ids? True
# is 5e948334-b8af-4c71-ad26-3a2e208fc20a in questions_ids? False
# inserting qas with ids ['13a46eb1-5461-465d-8980-62f633929539'] for split test
# paragraph['qas'] size: 1 for split test
# is 94c657cf-76c8-4082-be75-42f392fab13b in questions_ids? True
# is 0cef20b2-b3fe-4624-bbb2-f231d0bea478 in questions_ids? False
# inserting qas with ids ['94c657cf-76c8-4082-be75-42f392fab13b'] for split test
# paragraph['qas'] size: 1 for split test
# is bfe2ee13-f50f-4c90-a128-6b98f96d364b in questions_ids? True
# is 6422a85e-362a-4e39-98b1-2b48897a5dbf in questions_ids? False
# inserting qas with ids ['bfe2ee13-f50f-4c90-a128-6b98f96d364b'] for split test
# paragraph['qas'] size: 1 for split test
# is eadb1b89-9c1e-4c5c-82cf-c29a4c836701 in questions_ids? False
# is bc1b5c0a-63af-47df-8205-cf58d1abbabc in questions_ids? False
# inserting qas with ids [] for split test
# paragraph['qas'] size: 0 for split test

# %% [markdown]
# ## Verify no questions with less than 3 embeddings after split

# %%
train_data = json.load(open("../data/generated/train.json", "r", encoding="utf-8"))
test_data = json.load(open("../data/generated/test.json", "r", encoding="utf-8"))

# %%
train_qs_to_remove = []

for item in train_data["data"]:
    for paragraph in item["paragraphs"]:
        if len(paragraph["embedding_ids"]) < 3:
            for qa in paragraph["qas"]:
                train_qs_to_remove.append(qa["id"])

# %%
test_qs_to_remove = []

for item in test_data["data"]:
    for paragraph in item["paragraphs"]:
        if len(paragraph["embedding_ids"]) < 3:
            for qa in paragraph["qas"]:
                test_qs_to_remove.append(qa["id"])

# %%
print([id for id in train_qs_to_remove])
print([id for id in test_qs_to_remove])
# Out:
# []
# []

# %% [markdown]
# ## Train, Test stats

# %%
# Calculate number of questions and answers

from modules.document.utils.policyqa_parser import *

file_path = "../data/generated/train.json"


num_questions = count_questions(file_path)
num_answers = count_answers(file_path)
avg_answer_size = calculate_avg_answer_size(file_path)
min_answer_size, max_answer_size = calculate_min_max_answer_size(file_path)
min_context_size, max_context_size = calculate_min_max_context_size(file_path)

print("train dataset stats")
print(f"Number of questions: {num_questions}")
print(f"Number of answers: {num_answers}")
print(f"Average answer size: {avg_answer_size}")
print(f"Min answer size: {min_answer_size}")
print(f"Max answer size: {max_answer_size}")
print(f"Min context size: {min_context_size}")
print(f"Max context size: {max_context_size}")
# Out:
# train dataset stats
# Number of questions: 273
# Number of answers: 273
# Average answer size: 326.5274725274725
# Min answer size: 4
# Max answer size: 1252
# Min context size: 36
# Max context size: 5791

# %%
# Calculate number of questions and answers

from modules.document.utils.policyqa_parser import *

file_path = "../data/generated/test.json"


num_questions = count_questions(file_path)
num_answers = count_answers(file_path)
avg_answer_size = calculate_avg_answer_size(file_path)
min_answer_size, max_answer_size = calculate_min_max_answer_size(file_path)
min_context_size, max_context_size = calculate_min_max_context_size(file_path)

print("test dataset stats")
print(f"Number of questions: {num_questions}")
print(f"Number of answers: {num_answers}")
print(f"Average answer size: {avg_answer_size}")
print(f"Min answer size: {min_answer_size}")
print(f"Max answer size: {max_answer_size}")
print(f"Min context size: {min_context_size}")
print(f"Max context size: {max_context_size}")
# Out:
# test dataset stats
# Number of questions: 263
# Number of answers: 263
# Average answer size: 329.5665399239544
# Min answer size: 15
# Max answer size: 1091
# Min context size: 36
# Max context size: 5791

# %% [markdown]
# ## Check if we get the same result from GPT4 given the context

# %%
len(answer_in_context_df)
#get question and answers from training data

file_path = "../data/generated/train.json"

train_q_ids = []

with open(file_path, "r", encoding="utf8") as f:
    data = json.load(f)
    for item in data["data"]:
        title = item["title"]
        source = item["source"]
        for paragraph in item["paragraphs"]:
            for qa in paragraph["qas"]:
                train_q_ids.append(qa["id"])

print("number of questions in training data: ", len(train_q_ids))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 len(answer_in_context_df)
#       2 #get question and answers from training data
#       4 file_path = "../data/generated/train.json"
#
# NameError: name 'answer_in_context_df' is not defined

# %%
train_answers_in_context_df = answer_in_context_df.loc[answer_in_context_df["id"].isin(train_q_ids)]

# %%
len(train_answers_in_context_df)
# Out:
# 273

# %%
train_q_ids_in_context = train_answers_in_context_df["id"].tolist()

# %%
len(train_q_ids_in_context)
# Out:
# 273

# %%
from modules.llm.clients.openai.azure_openai_client import AzureOpenAILLMClient
from modules.llm.clients.open_source.local_llm_client import LocalLLMClient
from modules.llm.llm_infos import Model

# %% [markdown]
# ## Upper bound evaluation

# %%
DATASET = "train"
DATASET_FILE = f"../data/generated/{DATASET}.json"
RESULT_FILE = f"../data/generated/results/upper_bound_{DATASET}_saul.json"

print(f'DATASET_FILE: {DATASET_FILE}')
print(f'RESULT_FILE: {RESULT_FILE}')
# Out:
# DATASET_FILE: ../data/generated/train.json
# RESULT_FILE: ../data/generated/results/upper_bound_train_saul.json

# %%
from modules.answer.schemas import AnswerCreate
import time
import os
import json
from tqdm import tqdm
import logging
from collections import deque
from modules.embedding.service import get as get_embedding_by_id

#rate_limit_per_minute = 9600 # values from azure
#tokens_per_minute = 40000 # values from azure
rate_limit_per_minute = float("inf") # local values
tokens_per_minute = float("inf") # local values
delay = 60.0 / rate_limit_per_minute

def get_saved_qas(file_path: str):
    saved_qas = []
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as f:
            json_data = json.load(f)
            if "data" in json_data:
                for qa in json_data["data"]:
                    saved_qas.append(qa["id"])
    return saved_qas

def filter_embeddings(embeddings, answers):
    relevant_embeddings = [embedding for embedding in embeddings if any(answer for answer in answers if answer['text'] in embedding.text)]
    if len(relevant_embeddings) > 3:
        relevant_embeddings = relevant_embeddings[:3]
    return relevant_embeddings

def filter_embeddings_context(embeddings, context):
    relevant_embeddings = [embedding for embedding in embeddings if context == embedding.text]
    return relevant_embeddings

#def filter_embedding_with_answer(embeddings, answer):
#    if answer.endswith("."):
#        answer = answer[:-1]
#    answer = " ".join(answer.split())
#    filtered_embeddings = [embedding for embedding in embeddings if answer.lower()
#                           in " ".join(embedding.text.lower().replace("\n", " ").split())]
#    return filtered_embeddings

def filter_embedding_with_answer(embeddings, answer):
    if answer.endswith("."):
        answer = answer[:-1]
    answer = " ".join(answer.split())    
    filtered_embeddings = [embedding for embedding in embeddings if answer.lower()
                           in " ".join(embedding.text.lower().replace("\n", " ").split())]
    return filtered_embeddings

def map_relevant_embeddings(embeddings):
    relevant_embeddings = []
    for i, embedding in enumerate(embeddings):
        relevant_embedding = {}
        relevant_embedding["embedding_id"] = str(embedding.id)
        relevant_embedding["rank"] = i+1
        relevant_embedding["title"] = embedding.document.title
        relevant_embedding["offset"] = embedding.offset
        relevant_embedding["text"] = embedding.text
        relevant_embedding["score"] = 0.0
        relevant_embeddings.append(relevant_embedding)
    return relevant_embeddings

async def run_all_qas(file_path: str, model: Model=Model.AZURE_GPT4) -> None:
    qs_multiple_embeds = [] #remove later
    running_tokens = 0
    total_tokens = 0
    start_time = time.time()
    results = {"data": []}

    # check if there are saved results and load them
    saved_qas = get_saved_qas(RESULT_FILE)
    if len(saved_qas) > 0:
        with open(RESULT_FILE, "r", encoding="utf-8") as f:
            results = json.load(f)

    with open(file_path, "r", encoding="utf-8") as f:
        json_data = json.load(f)
        if "data" in json_data:
            for regulation in tqdm(json_data["data"]):
                title = regulation["title"]
                logging.info(f"processing regulation: {title}")
                for i, paragraph in tqdm(enumerate(regulation["paragraphs"])):
                    context = paragraph["context"]
                    for qa in paragraph["qas"]:
                        q_id = qa["id"]
                        if q_id in saved_qas:
                            print(f"skipping question {q_id} because it is already saved")
                            continue
                        question = qa["question"]
                        answers = qa["answers"]
                        embed_ids = paragraph["embedding_ids"]
                        request = AnswerCreate(
                            question=question,
                            model=model,
                            prompt=f"""You are a legal expert in ESG regulation, please give a concise answer to the question based on the given context. The answer must be an exact excerpt extracted from the given context that answers the question. Make sure to not add any additional or irrelevant information to the answer. Do not add quotes around the answer"""
                        )

                        if running_tokens > tokens_per_minute*0.8 and time.time() - start_time < 60.0:
                            time.sleep((time.time() - start_time)+15)
                            start_time = time.time()
                            running_tokens = 0

                        ## switch here to get embeddings from context or from document
                        #filtered_embeddings = filter_embeddings(embeddings, answers)
                        filtered_embeddings = [get_embedding_by_id(embed_id) for embed_id in embed_ids]
                        filtered_embeddings = filter_embedding_with_answer(filtered_embeddings, answers[0]["text"])
                        if len(filtered_embeddings) == 0:
                            print(f"no embeddings found for question {q_id}")
                        #filtered_embeddings = filter_embeddings_context(embeddings, context)
                        #llm_client = AzureOpenAILLMClient(Model.AZURE_GPT4)
                        llm_client = LocalLLMClient(Model.Mistral)
                        llm_client.prompt = request.prompt
                        prompt = llm_client.generate_prompt(request.question, filtered_embeddings)
                        num_tokens_prompt = len(llm_client.token_encoding.encode(prompt))
                        #llm_client.priming = f'[INST]{llm_client.priming}[/INST] '
                        num_tokens_priming = len(llm_client.token_encoding.encode(llm_client.priming))
                        num_tokens = num_tokens_prompt + num_tokens_priming
                        print(f'total tokens sent to LLM: {num_tokens}')
                        #answer_generator = llm_client.get_completion(f'[INST]{prompt}[/INST]')
                        answer_generator = llm_client.get_completion(prompt)

                        running_tokens += num_tokens
                        total_tokens += num_tokens
                        time.sleep(delay)
                        answer_text = ""
                        for answer in answer_generator:
                            answer_text += answer
                        results["data"].append({
                            "title": title,
                            "id": q_id,
                            "question": question,
                            "answers": answers,
                            "pred_answer": answer_text,
                            "relevant_embeddings": map_relevant_embeddings(filtered_embeddings)
                        })
                    # save results to file after each paragraph
                    with open(RESULT_FILE, "w", encoding="utf-8") as f:
                        json.dump(results, f, indent=4, ensure_ascii=False)
                        print(f"saved results to {RESULT_FILE} for title {title} paragraph {i}")
    print(f"total tokens used: {total_tokens}")

# %%
await run_all_qas(DATASET_FILE, model=Model.Mistral)

# %%
DATASET = "train"
DATASET_FILE = f"../data/generated/{DATASET}.json"
RESULT_FILE = f"../data/generated/results/upper_bound_{DATASET}_saul.json"

print(f'DATASET_FILE: {DATASET_FILE}')
print(f'RESULT_FILE: {RESULT_FILE}')
# Out:
# DATASET_FILE: ../data/generated/train.json
# RESULT_FILE: ../data/generated/results/upper_bound_train_saul.json

# %%
from backend.evals.torchmetrics_eval_script import eval_squad_metrics

eval_squad_metrics(RESULT_FILE)
# Out:
# 100%|██████████| 273/273 [00:00<?, ?it/s]
# {'exact_match': tensor(25.2747), 'f1': tensor(78.6480)}

# %%
# difference likely due to data cleaning (special char removal, lowercasing, etc.)
from backend.evals.squad_eval_script import Evaluator
import json

evaluator = Evaluator(DATASET_FILE)
em, f1, precision, recall = evaluator.evaluate(RESULT_FILE)
print(f"Exact Match: {em}\n F1-measure: {f1}\n Precision: {precision}\n Recall: {recall}")
# Out:
# Exact Match: 24.90842490842491
#  F1-measure: 78.93270803518888
#  Precision: 84.90809373470881
#  Recall: 82.47921004174734

# %%
json_data = json.load(open(RESULT_FILE, "r", encoding="utf-8"))
for item in json_data["data"]:
    if len(item['relevant_embeddings']) > 1:
        print(f"question: {item['id']}")
# Out:
# question: 3e06f40c-9294-43a7-aa1a-69a3a8c95e24
# question: 8bdfbbf1-4cb6-4e97-9d1c-095889f19e84
# question: f576ac40-7742-4da7-ae02-a6dbd6c7ca5d

# %%
from backend.evals.torchmetrics_eval_script import eval_retrieval_metrics
from tqdm import tqdm
import logging

logging.disable(logging.INFO)

retrieval_metrics = []
top_k=1
for i in tqdm(range(1, top_k+1)):
    retrieval_metrics.append(eval_retrieval_metrics(RESULT_FILE, top_k=i))

for retrieval_metrics in retrieval_metrics:
    print(f'{retrieval_metrics}')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 273it [00:00, 37395.33it/s]
#
#   0%|          | 0/273 [00:00<?, ?it/s]
#  22%|██▏       | 60/273 [00:00<00:00, 599.04it/s]
#  44%|████▍     | 120/273 [00:00<00:00, 485.25it/s]
#  62%|██████▏   | 170/273 [00:00<00:00, 393.61it/s]
#  78%|███████▊  | 212/273 [00:00<00:00, 340.69it/s]
# 100%|██████████| 273/273 [00:00<00:00, 294.09it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
# {'map@1': tensor(1.), 'mrr@1': tensor(1.), '%Answers found@1': tensor(1.), '%Relevant embeddings@1': tensor(1.)}

# %% [markdown]
# ## RAG evaluation

# %%
DATASET = "train"
DATASET_FILE = f"../data/generated/{DATASET}.json"
RESULT_FILE = f"../data/generated/results/{DATASET}_saul.json"

print(f'DATASET_FILE: {DATASET_FILE}')
print(f'RESULT_FILE: {RESULT_FILE}')
# Out:
# DATASET_FILE: ../data/generated/train.json
# RESULT_FILE: ../data/generated/results/train_saul.json

# %%
from modules.llm.clients.openai.azure_openai_client import AzureOpenAILLMClient
from modules.llm.clients.open_source.local_llm_client import LocalLLMClient
from modules.llm.llm_infos import Model

# %%
from modules.answer.schemas import AnswerCreate
from modules.answer.service import create as create_answer
import time
import os
import json
from tqdm import tqdm
import logging

#rate_limit_per_minute = 9600 # values from azure
#tokens_per_minute = 40000 # values from azure
rate_limit_per_minute = float("inf") # local values
tokens_per_minute = float("inf") # local values
delay = 60.0 / rate_limit_per_minute

def get_saved_qas(file_path: str):
    saved_qas = []
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as f:
            json_data = json.load(f)
            if "data" in json_data:
                for qa in json_data["data"]:
                    saved_qas.append(qa["id"])
    return saved_qas

async def run_all_qas(file_path: str, model: Model=Model.AZURE_GPT4) -> None:
    running_tokens = 0
    total_tokens = 0
    start_time = time.time()
    results = {"data": []}

    # check if there are saved results and load them
    saved_qas = get_saved_qas(RESULT_FILE)
    if len(saved_qas) > 0:
        with open(RESULT_FILE, "r", encoding="utf-8") as f:
            results = json.load(f)

    with open(file_path, "r", encoding="utf-8") as f:
        json_data = json.load(f)
        if "data" in json_data:
            for regulation in tqdm(json_data["data"]):
                title = regulation["title"]
                logging.info(f"processing regulation: {title}")
                for i, paragraph in tqdm(enumerate(regulation["paragraphs"])):
                    context = paragraph["context"]
                    for qa in paragraph["qas"]:
                        q_id = qa["id"]
                        if q_id in saved_qas:
                            print(f"skipping question {q_id} because it is already saved")
                            continue
                        question = qa["question"]
                        answers = qa["answers"]
                        embed_ids = paragraph["embedding_ids"]
                        request = AnswerCreate(
                            question=question,
                            model=model,
                            prompt=f"""You are a legal expert in ESG regulation, please give a concise answer to the question based on the given context. The answer must be an exact excerpt extracted from the given context that answers the question. Make sure to not add any additional or irrelevant information to the answer. Do not add quotes around the answer"""
                        )

                        if running_tokens > tokens_per_minute*0.8 and time.time() - start_time < 60.0:
                            time.sleep((time.time() - start_time)+15)
                            start_time = time.time()
                            running_tokens = 0

                        question_embedding, answer_embeddings, answer_generator, num_tokens = await create_answer(request)

                        running_tokens += num_tokens
                        total_tokens += num_tokens
                        
                        time.sleep(delay)
                        
                        answer_text = ""
                        for answer in answer_generator:
                            answer_text += answer
                            
                        results["data"].append({
                            "title": title,
                            "id": q_id,
                            "question": question,
                            "answers": answers,
                            "pred_answer": answer_text,
                            "relevant_embeddings": answer_embeddings
                        })
                    # save results to file after each paragraph
                    with open(RESULT_FILE, "w", encoding="utf-8") as f:
                        json.dump(results, f, indent=4, ensure_ascii=False)
                        print(f"saved results to {RESULT_FILE} for title {title} paragraph {i}")
    print(f"total tokens used: {total_tokens}")

# %%
await run_all_qas(DATASET_FILE, model=Model.Mistral)

# %%
from backend.evals.torchmetrics_eval_script import eval_squad_metrics

eval_squad_metrics(RESULT_FILE)
# Out:
# 100%|██████████| 273/273 [00:00<?, ?it/s]
# {'exact_match': tensor(10.2564), 'f1': tensor(59.2367)}

# %%
# difference likely due to data cleaning (special char removal, lowercasing, etc.)
from backend.evals.squad_eval_script import Evaluator
import json

evaluator = Evaluator(DATASET_FILE)
em, f1, precision, recall = evaluator.evaluate(RESULT_FILE)
print(f"Exact Match: {em}\n F1-measure: {f1}\n Precision: {precision}\n Recall: {recall}")
# Out:
# Exact Match: 9.157509157509157
#  F1-measure: 59.847281423667184
#  Precision: 60.98790710767221
#  Recall: 70.80651253693225

# %%
from backend.evals.torchmetrics_eval_script import eval_retrieval_metrics
from tqdm import tqdm
import logging

logging.disable(logging.INFO)

retrieval_metrics = []
top_k=3
for i in tqdm(range(1, top_k+1)):
    retrieval_metrics.append(eval_retrieval_metrics(RESULT_FILE, top_k=i))

for retrieval_metrics in retrieval_metrics:
    print(f'{retrieval_metrics}')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 273it [00:00, 68185.85it/s]
#
#   0%|          | 0/273 [00:00<?, ?it/s]
#  14%|█▍        | 39/273 [00:00<00:00, 386.22it/s]
#  38%|███▊      | 103/273 [00:00<00:00, 529.92it/s]
#  57%|█████▋    | 156/273 [00:00<00:00, 468.67it/s]
#  75%|███████▍  | 204/273 [00:00<00:00, 385.40it/s]
# 100%|██████████| 273/273 [00:00<00:00, 284.11it/s]
# C:\Users\onan\IdeaProjects\ai4esg_experiments_new\backend\evals\torchmetrics_eval_script.py:84: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   relevant_embeddings_ratio = torch.tensor(sum(targets) / len(targets))
#  33%|███▎      | 1/3 [00:01<00:02,  1.02s/it]
# 273it [00:00, 35938.77it/s]
#
#   0%|          | 0/273 [00:00<?, ?it/s]
#  30%|███       | 83/273 [00:00<00:00, 826.95it/s]
#  61%|██████    | 166/273 [00:00<00:00, 473.82it/s]
#  81%|████████▏ | 222/273 [00:00<00:00, 338.77it/s]
# 100%|██████████| 273/273 [00:00<00:00, 333.54it/s]
#  67%|██████▋   | 2/3 [00:01<00:00,  1.08it/s]
# 273it [00:00, 22414.94it/s]
#
#   0%|          | 0/273 [00:00<?, ?it/s]
#  32%|███▏      | 88/273 [00:00<00:00, 871.66it/s]
#  64%|██████▍   | 176/273 [00:00<00:00, 525.91it/s]
# 100%|██████████| 273/273 [00:00<00:00, 379.62it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.13it/s]
# {'map@1': tensor(0.5275), 'mrr@1': tensor(0.5275), '%Answers found@1': tensor(0.5275), '%Relevant embeddings@1': tensor(0.5275)}
# {'map@2': tensor(0.5916), 'mrr@2': tensor(0.5916), '%Answers found@2': tensor(0.6557), '%Relevant embeddings@2': tensor(0.3370)}
# {'map@3': tensor(0.6154), 'mrr@3': tensor(0.6160), '%Answers found@3': tensor(0.7289), '%Relevant embeddings@3': tensor(0.2527)}
